# %% [markdown]
# ### Data/Label Organizer
#
# #### This script is to tidy data/label pairs and organize the folder structure for Yolo Model Intake. The script will perform the following:
# 1) Import the folder where data/labels are stored
# 2) Match file name convention for utilization in model
# 3) Identify the label id and their respective names
# 4) Setup folder structure
# 5) Populate structure to begin inferencing on main script
#
# #### We will go over each kernel to explain the steps

# %%
### Lets import the modules needed for this task:

import os
import shutil
import pandas as pd
from pathlib import Path
import re
import random

# %% [markdown]
# #### 1) Import the folder where data/labels are stored

# %%
### Import image folder

imgData = Path('./MODELDATA\Cleanse_v1-20251104T204656Z-1-001\Cleanse_v1')

### Import Annotations for cleansed data images
### The images cleansed were extracted from VID02, VID04, VID05, VID06, and VID10
### Therefore lets retrieve those respective folders only to pair up.

annotVID02 = Path('./MODELDATA\yolo_annotations\yolo_annotations\VID02')
annotVID04 = Path('./MODELDATA\yolo_annotations\yolo_annotations\VID04')
annotVID05 = Path('./MODELDATA\yolo_annotations\yolo_annotations\VID05')
annotVID06 = Path('./MODELDATA\yolo_annotations\yolo_annotations\VID06')
annotVID10 = Path('./MODELDATA\yolo_annotations\yolo_annotations\VID10')

# %% [markdown]
# #### 2) Match file name convention for utilization in model

# %%
### We have to edit the name of annotations to match the image naming convention to be able to pair up
### Since the images are named "VID02_000..." while the annotations are named "VID_2_000...."
### We have to edit recursively

### Lets copy the respective folders to avoid editing original files

ann_folders = [annotVID02, annotVID04, annotVID05, annotVID06, annotVID10]

backup_root = Path("./annot_backup")
backup_root.mkdir(exist_ok=True)

copied_folders = []

for folder in ann_folders:
    dest = backup_root / folder.name
    if dest.exists():
        shutil.rmtree(dest)  ### Remove backup incase of re-run
    shutil.copytree(folder, dest)
    copied_folders.append(dest)
    print(f"Copied {folder} → {dest}")
# Out:
# Copied MODELDATA\yolo_annotations\yolo_annotations\VID02 → annot_backup\VID02
# Copied MODELDATA\yolo_annotations\yolo_annotations\VID04 → annot_backup\VID04
# Copied MODELDATA\yolo_annotations\yolo_annotations\VID05 → annot_backup\VID05
# Copied MODELDATA\yolo_annotations\yolo_annotations\VID06 → annot_backup\VID06
# Copied MODELDATA\yolo_annotations\yolo_annotations\VID10 → annot_backup\VID10

# %%
### Lets change the file names accordingly and recursively

pattern = re.compile(r"^VID_(\d+)_(.+)$", re.I)

for folder in copied_folders:
    for file in folder.rglob("*.txt"):
        m = pattern.match(file.stem)
        if not m:
            continue
        
        num = m.group(1)      ###number part (after VID_)
        rest = m.group(2)     ###rest of the filename

        ###Pad single digits and double digits just move
        if len(num) == 1:
            num = f"0{num}"

        new_name = f"VID{num}_{rest}{file.suffix}"
        new_path = file.with_name(new_name)

        file.rename(new_path)
        print(f"Renamed: {file.name} → {new_name}")
# Out:
# Renamed: VID_2_000000.txt → VID02_000000.txt
# Renamed: VID_2_000001.txt → VID02_000001.txt
# Renamed: VID_2_000002.txt → VID02_000002.txt
# Renamed: VID_2_000003.txt → VID02_000003.txt
# Renamed: VID_2_000004.txt → VID02_000004.txt
# Renamed: VID_2_000005.txt → VID02_000005.txt
# Renamed: VID_2_000006.txt → VID02_000006.txt
# Renamed: VID_2_000007.txt → VID02_000007.txt
# Renamed: VID_2_000008.txt → VID02_000008.txt
# Renamed: VID_2_000009.txt → VID02_000009.txt
# Renamed: VID_2_000010.txt → VID02_000010.txt
# Renamed: VID_2_000011.txt → VID02_000011.txt
# Renamed: VID_2_000012.txt → VID02_000012.txt
# Renamed: VID_2_000013.txt → VID02_000013.txt
# Renamed: VID_2_000014.txt → VID02_000014.txt
# Renamed: VID_2_000015.txt → VID02_000015.txt
# Renamed: VID_2_000016.txt → VID02_000016.txt
# Renamed: VID_2_000017.txt → VID02_000017.txt
# Renamed: VID_2_000018.txt → VID02_000018.txt
# Renamed: VID_2_000019.txt → VID02_000019.txt
# Renamed: VID_2_000020.txt → VID02_000020.txt
# Renamed: VID_2_000021.txt → VID02_000021.txt
# Renamed: VID_2_000022.txt → VID02_000022.txt
# Renamed: VID_2_000023.txt → VID02_000023.txt
# Renamed: VID_2_000024.txt → VID02_000024.txt
# Renamed: VID_2_000025.txt → VID02_000025.txt
# Renamed: VID_2_000026.txt → VID02_000026.txt
# Renamed: VID_2_000027.txt → VID02_000027.txt
# Renamed: VID_2_000028.txt → VID02_000028.txt
# Renamed: VID_2_000029.txt → VID02_000029.txt
# Renamed: VID_2_000030.txt → VID02_000030.txt
# Renamed: VID_2_000031.txt → VID02_000031.txt
# Renamed: VID_2_000032.txt → VID02_000032.txt
# Renamed: VID_2_000033.txt → VID02_000033.txt
# Renamed: VID_2_000034.txt → VID02_000034.txt
# Renamed: VID_2_000035.txt → VID02_000035.txt
# Renamed: VID_2_000036.txt → VID02_000036.txt
# Renamed: VID_2_000037.txt → VID02_000037.txt
# Renamed: VID_2_000038.txt → VID02_000038.txt
# Renamed: VID_2_000039.txt → VID02_000039.txt
# Renamed: VID_2_000040.txt → VID02_000040.txt
# Renamed: VID_2_000041.txt → VID02_000041.txt
# Renamed: VID_2_000042.txt → VID02_000042.txt
# Renamed: VID_2_000043.txt → VID02_000043.txt
# Renamed: VID_2_000044.txt → VID02_000044.txt
# Renamed: VID_2_000045.txt → VID02_000045.txt
# Renamed: VID_2_000046.txt → VID02_000046.txt
# Renamed: VID_2_000047.txt → VID02_000047.txt
# Renamed: VID_2_000048.txt → VID02_000048.txt
# Renamed: VID_2_000049.txt → VID02_000049.txt
# Renamed: VID_2_000050.txt → VID02_000050.txt
# Renamed: VID_2_000051.txt → VID02_000051.txt
# Renamed: VID_2_000052.txt → VID02_000052.txt
# Renamed: VID_2_000053.txt → VID02_000053.txt
# Renamed: VID_2_000054.txt → VID02_000054.txt
# Renamed: VID_2_000055.txt → VID02_000055.txt
# Renamed: VID_2_000056.txt → VID02_000056.txt
# Renamed: VID_2_000057.txt → VID02_000057.txt
# Renamed: VID_2_000058.txt → VID02_000058.txt
# Renamed: VID_2_000059.txt → VID02_000059.txt
# Renamed: VID_2_000060.txt → VID02_000060.txt
# Renamed: VID_2_000061.txt → VID02_000061.txt
# Renamed: VID_2_000062.txt → VID02_000062.txt
# Renamed: VID_2_000063.txt → VID02_000063.txt
# Renamed: VID_2_000064.txt → VID02_000064.txt
# Renamed: VID_2_000065.txt → VID02_000065.txt
# Renamed: VID_2_000066.txt → VID02_000066.txt
# Renamed: VID_2_000067.txt → VID02_000067.txt
# Renamed: VID_2_000068.txt → VID02_000068.txt
# Renamed: VID_2_000069.txt → VID02_000069.txt
# Renamed: VID_2_000070.txt → VID02_000070.txt
# Renamed: VID_2_000071.txt → VID02_000071.txt
# Renamed: VID_2_000072.txt → VID02_000072.txt
# Renamed: VID_2_000073.txt → VID02_000073.txt
# Renamed: VID_2_000074.txt → VID02_000074.txt
# Renamed: VID_2_000075.txt → VID02_000075.txt
# Renamed: VID_2_000076.txt → VID02_000076.txt
# Renamed: VID_2_000077.txt → VID02_000077.txt
# Renamed: VID_2_000078.txt → VID02_000078.txt
# Renamed: VID_2_000079.txt → VID02_000079.txt
# Renamed: VID_2_000080.txt → VID02_000080.txt
# Renamed: VID_2_000081.txt → VID02_000081.txt
# Renamed: VID_2_000082.txt → VID02_000082.txt
# Renamed: VID_2_000083.txt → VID02_000083.txt
# Renamed: VID_2_000084.txt → VID02_000084.txt
# Renamed: VID_2_000085.txt → VID02_000085.txt
# Renamed: VID_2_000086.txt → VID02_000086.txt
# Renamed: VID_2_000087.txt → VID02_000087.txt
# Renamed: VID_2_000088.txt → VID02_000088.txt
# Renamed: VID_2_000089.txt → VID02_000089.txt
# Renamed: VID_2_000090.txt → VID02_000090.txt
# Renamed: VID_2_000091.txt → VID02_000091.txt
# Renamed: VID_2_000092.txt → VID02_000092.txt
# Renamed: VID_2_000093.txt → VID02_000093.txt
# Renamed: VID_2_000094.txt → VID02_000094.txt
# Renamed: VID_2_000095.txt → VID02_000095.txt
# Renamed: VID_2_000096.txt → VID02_000096.txt
# Renamed: VID_2_000097.txt → VID02_000097.txt
# Renamed: VID_2_000098.txt → VID02_000098.txt
# Renamed: VID_2_000099.txt → VID02_000099.txt
# Renamed: VID_2_000100.txt → VID02_000100.txt
# Renamed: VID_2_000101.txt → VID02_000101.txt
# Renamed: VID_2_000102.txt → VID02_000102.txt
# Renamed: VID_2_000103.txt → VID02_000103.txt
# Renamed: VID_2_000104.txt → VID02_000104.txt
# Renamed: VID_2_000105.txt → VID02_000105.txt
# Renamed: VID_2_000106.txt → VID02_000106.txt
# Renamed: VID_2_000107.txt → VID02_000107.txt
# Renamed: VID_2_000108.txt → VID02_000108.txt
# Renamed: VID_2_000109.txt → VID02_000109.txt
# Renamed: VID_2_000110.txt → VID02_000110.txt
# Renamed: VID_2_000111.txt → VID02_000111.txt
# Renamed: VID_2_000112.txt → VID02_000112.txt
# Renamed: VID_2_000113.txt → VID02_000113.txt
# Renamed: VID_2_000114.txt → VID02_000114.txt
# Renamed: VID_2_000115.txt → VID02_000115.txt
# Renamed: VID_2_000116.txt → VID02_000116.txt
# Renamed: VID_2_000117.txt → VID02_000117.txt
# Renamed: VID_2_000118.txt → VID02_000118.txt
# Renamed: VID_2_000119.txt → VID02_000119.txt
# Renamed: VID_2_000120.txt → VID02_000120.txt
# Renamed: VID_2_000121.txt → VID02_000121.txt
# Renamed: VID_2_000122.txt → VID02_000122.txt
# Renamed: VID_2_000123.txt → VID02_000123.txt
# Renamed: VID_2_000124.txt → VID02_000124.txt
# Renamed: VID_2_000125.txt → VID02_000125.txt
# Renamed: VID_2_000126.txt → VID02_000126.txt
# Renamed: VID_2_000127.txt → VID02_000127.txt
# Renamed: VID_2_000128.txt → VID02_000128.txt
# Renamed: VID_2_000129.txt → VID02_000129.txt
# Renamed: VID_2_000130.txt → VID02_000130.txt
# Renamed: VID_2_000131.txt → VID02_000131.txt
# Renamed: VID_2_000132.txt → VID02_000132.txt
# Renamed: VID_2_000133.txt → VID02_000133.txt
# Renamed: VID_2_000134.txt → VID02_000134.txt
# Renamed: VID_2_000135.txt → VID02_000135.txt
# Renamed: VID_2_000136.txt → VID02_000136.txt
# Renamed: VID_2_000137.txt → VID02_000137.txt
# Renamed: VID_2_000138.txt → VID02_000138.txt
# Renamed: VID_2_000139.txt → VID02_000139.txt
# Renamed: VID_2_000140.txt → VID02_000140.txt
# Renamed: VID_2_000141.txt → VID02_000141.txt
# Renamed: VID_2_000142.txt → VID02_000142.txt
# Renamed: VID_2_000143.txt → VID02_000143.txt
# Renamed: VID_2_000144.txt → VID02_000144.txt
# Renamed: VID_2_000145.txt → VID02_000145.txt
# Renamed: VID_2_000146.txt → VID02_000146.txt
# Renamed: VID_2_000147.txt → VID02_000147.txt
# Renamed: VID_2_000148.txt → VID02_000148.txt
# Renamed: VID_2_000149.txt → VID02_000149.txt
# Renamed: VID_2_000150.txt → VID02_000150.txt
# Renamed: VID_2_000151.txt → VID02_000151.txt
# Renamed: VID_2_000152.txt → VID02_000152.txt
# Renamed: VID_2_000153.txt → VID02_000153.txt
# Renamed: VID_2_000154.txt → VID02_000154.txt
# Renamed: VID_2_000155.txt → VID02_000155.txt
# Renamed: VID_2_000156.txt → VID02_000156.txt
# Renamed: VID_2_000157.txt → VID02_000157.txt
# Renamed: VID_2_000158.txt → VID02_000158.txt
# Renamed: VID_2_000159.txt → VID02_000159.txt
# Renamed: VID_2_000160.txt → VID02_000160.txt
# Renamed: VID_2_000161.txt → VID02_000161.txt
# Renamed: VID_2_000162.txt → VID02_000162.txt
# Renamed: VID_2_000163.txt → VID02_000163.txt
# Renamed: VID_2_000164.txt → VID02_000164.txt
# Renamed: VID_2_000165.txt → VID02_000165.txt
# Renamed: VID_2_000166.txt → VID02_000166.txt
# Renamed: VID_2_000167.txt → VID02_000167.txt
# Renamed: VID_2_000168.txt → VID02_000168.txt
# Renamed: VID_2_000169.txt → VID02_000169.txt
# Renamed: VID_2_000170.txt → VID02_000170.txt
# Renamed: VID_2_000171.txt → VID02_000171.txt
# Renamed: VID_2_000172.txt → VID02_000172.txt
# Renamed: VID_2_000173.txt → VID02_000173.txt
# Renamed: VID_2_000174.txt → VID02_000174.txt
# Renamed: VID_2_000175.txt → VID02_000175.txt
# Renamed: VID_2_000176.txt → VID02_000176.txt
# Renamed: VID_2_000177.txt → VID02_000177.txt
# Renamed: VID_2_000178.txt → VID02_000178.txt
# Renamed: VID_2_000179.txt → VID02_000179.txt
# Renamed: VID_2_000180.txt → VID02_000180.txt
# Renamed: VID_2_000181.txt → VID02_000181.txt
# Renamed: VID_2_000182.txt → VID02_000182.txt
# Renamed: VID_2_000183.txt → VID02_000183.txt
# Renamed: VID_2_000184.txt → VID02_000184.txt
# Renamed: VID_2_000185.txt → VID02_000185.txt
# Renamed: VID_2_000186.txt → VID02_000186.txt
# Renamed: VID_2_000187.txt → VID02_000187.txt
# Renamed: VID_2_000188.txt → VID02_000188.txt
# Renamed: VID_2_000189.txt → VID02_000189.txt
# Renamed: VID_2_000190.txt → VID02_000190.txt
# Renamed: VID_2_000191.txt → VID02_000191.txt
# Renamed: VID_2_000192.txt → VID02_000192.txt
# Renamed: VID_2_000193.txt → VID02_000193.txt
# Renamed: VID_2_000194.txt → VID02_000194.txt
# Renamed: VID_2_000195.txt → VID02_000195.txt
# Renamed: VID_2_000196.txt → VID02_000196.txt
# Renamed: VID_2_000197.txt → VID02_000197.txt
# Renamed: VID_2_000198.txt → VID02_000198.txt
# Renamed: VID_2_000199.txt → VID02_000199.txt
# Renamed: VID_2_000200.txt → VID02_000200.txt
# Renamed: VID_2_000201.txt → VID02_000201.txt
# Renamed: VID_2_000202.txt → VID02_000202.txt
# Renamed: VID_2_000203.txt → VID02_000203.txt
# Renamed: VID_2_000204.txt → VID02_000204.txt
# Renamed: VID_2_000205.txt → VID02_000205.txt
# Renamed: VID_2_000206.txt → VID02_000206.txt
# Renamed: VID_2_000207.txt → VID02_000207.txt
# Renamed: VID_2_000208.txt → VID02_000208.txt
# Renamed: VID_2_000209.txt → VID02_000209.txt
# Renamed: VID_2_000210.txt → VID02_000210.txt
# Renamed: VID_2_000211.txt → VID02_000211.txt
# Renamed: VID_2_000212.txt → VID02_000212.txt
# Renamed: VID_2_000213.txt → VID02_000213.txt
# Renamed: VID_2_000214.txt → VID02_000214.txt
# Renamed: VID_2_000215.txt → VID02_000215.txt
# Renamed: VID_2_000216.txt → VID02_000216.txt
# Renamed: VID_2_000217.txt → VID02_000217.txt
# Renamed: VID_2_000218.txt → VID02_000218.txt
# Renamed: VID_2_000219.txt → VID02_000219.txt
# Renamed: VID_2_000220.txt → VID02_000220.txt
# Renamed: VID_2_000221.txt → VID02_000221.txt
# Renamed: VID_2_000222.txt → VID02_000222.txt
# Renamed: VID_2_000223.txt → VID02_000223.txt
# Renamed: VID_2_000224.txt → VID02_000224.txt
# Renamed: VID_2_000225.txt → VID02_000225.txt
# Renamed: VID_2_000226.txt → VID02_000226.txt
# Renamed: VID_2_000227.txt → VID02_000227.txt
# Renamed: VID_2_000228.txt → VID02_000228.txt
# Renamed: VID_2_000229.txt → VID02_000229.txt
# Renamed: VID_2_000230.txt → VID02_000230.txt
# Renamed: VID_2_000231.txt → VID02_000231.txt
# Renamed: VID_2_000232.txt → VID02_000232.txt
# Renamed: VID_2_000233.txt → VID02_000233.txt
# Renamed: VID_2_000234.txt → VID02_000234.txt
# Renamed: VID_2_000235.txt → VID02_000235.txt
# Renamed: VID_2_000236.txt → VID02_000236.txt
# Renamed: VID_2_000237.txt → VID02_000237.txt
# Renamed: VID_2_000238.txt → VID02_000238.txt
# Renamed: VID_2_000239.txt → VID02_000239.txt
# Renamed: VID_2_000240.txt → VID02_000240.txt
# Renamed: VID_2_000241.txt → VID02_000241.txt
# Renamed: VID_2_000242.txt → VID02_000242.txt
# Renamed: VID_2_000243.txt → VID02_000243.txt
# Renamed: VID_2_000244.txt → VID02_000244.txt
# Renamed: VID_2_000245.txt → VID02_000245.txt
# Renamed: VID_2_000246.txt → VID02_000246.txt
# Renamed: VID_2_000247.txt → VID02_000247.txt
# Renamed: VID_2_000248.txt → VID02_000248.txt
# Renamed: VID_2_000249.txt → VID02_000249.txt
# Renamed: VID_2_000250.txt → VID02_000250.txt
# Renamed: VID_2_000251.txt → VID02_000251.txt
# Renamed: VID_2_000252.txt → VID02_000252.txt
# Renamed: VID_2_000253.txt → VID02_000253.txt
# Renamed: VID_2_000254.txt → VID02_000254.txt
# Renamed: VID_2_000255.txt → VID02_000255.txt
# Renamed: VID_2_000256.txt → VID02_000256.txt
# Renamed: VID_2_000257.txt → VID02_000257.txt
# Renamed: VID_2_000258.txt → VID02_000258.txt
# Renamed: VID_2_000259.txt → VID02_000259.txt
# Renamed: VID_2_000260.txt → VID02_000260.txt
# Renamed: VID_2_000261.txt → VID02_000261.txt
# Renamed: VID_2_000262.txt → VID02_000262.txt
# Renamed: VID_2_000263.txt → VID02_000263.txt
# Renamed: VID_2_000264.txt → VID02_000264.txt
# Renamed: VID_2_000265.txt → VID02_000265.txt
# Renamed: VID_2_000266.txt → VID02_000266.txt
# Renamed: VID_2_000267.txt → VID02_000267.txt
# Renamed: VID_2_000268.txt → VID02_000268.txt
# Renamed: VID_2_000269.txt → VID02_000269.txt
# Renamed: VID_2_000270.txt → VID02_000270.txt
# Renamed: VID_2_000271.txt → VID02_000271.txt
# Renamed: VID_2_000272.txt → VID02_000272.txt
# Renamed: VID_2_000273.txt → VID02_000273.txt
# Renamed: VID_2_000274.txt → VID02_000274.txt
# Renamed: VID_2_000275.txt → VID02_000275.txt
# Renamed: VID_2_000276.txt → VID02_000276.txt
# Renamed: VID_2_000277.txt → VID02_000277.txt
# Renamed: VID_2_000278.txt → VID02_000278.txt
# Renamed: VID_2_000279.txt → VID02_000279.txt
# Renamed: VID_2_000280.txt → VID02_000280.txt
# Renamed: VID_2_000281.txt → VID02_000281.txt
# Renamed: VID_2_000282.txt → VID02_000282.txt
# Renamed: VID_2_000283.txt → VID02_000283.txt
# Renamed: VID_2_000284.txt → VID02_000284.txt
# Renamed: VID_2_000285.txt → VID02_000285.txt
# Renamed: VID_2_000286.txt → VID02_000286.txt
# Renamed: VID_2_000287.txt → VID02_000287.txt
# Renamed: VID_2_000288.txt → VID02_000288.txt
# Renamed: VID_2_000289.txt → VID02_000289.txt
# Renamed: VID_2_000290.txt → VID02_000290.txt
# Renamed: VID_2_000291.txt → VID02_000291.txt
# Renamed: VID_2_000292.txt → VID02_000292.txt
# Renamed: VID_2_000293.txt → VID02_000293.txt
# Renamed: VID_2_000294.txt → VID02_000294.txt
# Renamed: VID_2_000295.txt → VID02_000295.txt
# Renamed: VID_2_000296.txt → VID02_000296.txt
# Renamed: VID_2_000297.txt → VID02_000297.txt
# Renamed: VID_2_000298.txt → VID02_000298.txt
# Renamed: VID_2_000299.txt → VID02_000299.txt
# Renamed: VID_2_000300.txt → VID02_000300.txt
# Renamed: VID_2_000301.txt → VID02_000301.txt
# Renamed: VID_2_000302.txt → VID02_000302.txt
# Renamed: VID_2_000303.txt → VID02_000303.txt
# Renamed: VID_2_000304.txt → VID02_000304.txt
# Renamed: VID_2_000305.txt → VID02_000305.txt
# Renamed: VID_2_000306.txt → VID02_000306.txt
# Renamed: VID_2_000307.txt → VID02_000307.txt
# Renamed: VID_2_000308.txt → VID02_000308.txt
# Renamed: VID_2_000309.txt → VID02_000309.txt
# Renamed: VID_2_000310.txt → VID02_000310.txt
# Renamed: VID_2_000311.txt → VID02_000311.txt
# Renamed: VID_2_000312.txt → VID02_000312.txt
# Renamed: VID_2_000313.txt → VID02_000313.txt
# Renamed: VID_2_000314.txt → VID02_000314.txt
# Renamed: VID_2_000315.txt → VID02_000315.txt
# Renamed: VID_2_000316.txt → VID02_000316.txt
# Renamed: VID_2_000317.txt → VID02_000317.txt
# Renamed: VID_2_000318.txt → VID02_000318.txt
# Renamed: VID_2_000319.txt → VID02_000319.txt
# Renamed: VID_2_000320.txt → VID02_000320.txt
# Renamed: VID_2_000321.txt → VID02_000321.txt
# Renamed: VID_2_000322.txt → VID02_000322.txt
# Renamed: VID_2_000323.txt → VID02_000323.txt
# Renamed: VID_2_000324.txt → VID02_000324.txt
# Renamed: VID_2_000325.txt → VID02_000325.txt
# Renamed: VID_2_000326.txt → VID02_000326.txt
# Renamed: VID_2_000327.txt → VID02_000327.txt
# Renamed: VID_2_000328.txt → VID02_000328.txt
# Renamed: VID_2_000329.txt → VID02_000329.txt
# Renamed: VID_2_000330.txt → VID02_000330.txt
# Renamed: VID_2_000331.txt → VID02_000331.txt
# Renamed: VID_2_000332.txt → VID02_000332.txt
# Renamed: VID_2_000333.txt → VID02_000333.txt
# Renamed: VID_2_000334.txt → VID02_000334.txt
# Renamed: VID_2_000335.txt → VID02_000335.txt
# Renamed: VID_2_000336.txt → VID02_000336.txt
# Renamed: VID_2_000337.txt → VID02_000337.txt
# Renamed: VID_2_000338.txt → VID02_000338.txt
# Renamed: VID_2_000339.txt → VID02_000339.txt
# Renamed: VID_2_000340.txt → VID02_000340.txt
# Renamed: VID_2_000341.txt → VID02_000341.txt
# Renamed: VID_2_000342.txt → VID02_000342.txt
# Renamed: VID_2_000343.txt → VID02_000343.txt
# Renamed: VID_2_000344.txt → VID02_000344.txt
# Renamed: VID_2_000345.txt → VID02_000345.txt
# Renamed: VID_2_000346.txt → VID02_000346.txt
# Renamed: VID_2_000347.txt → VID02_000347.txt
# Renamed: VID_2_000348.txt → VID02_000348.txt
# Renamed: VID_2_000349.txt → VID02_000349.txt
# Renamed: VID_2_000350.txt → VID02_000350.txt
# Renamed: VID_2_000351.txt → VID02_000351.txt
# Renamed: VID_2_000352.txt → VID02_000352.txt
# Renamed: VID_2_000353.txt → VID02_000353.txt
# Renamed: VID_2_000354.txt → VID02_000354.txt
# Renamed: VID_2_000355.txt → VID02_000355.txt
# Renamed: VID_2_000356.txt → VID02_000356.txt
# Renamed: VID_2_000357.txt → VID02_000357.txt
# Renamed: VID_2_000358.txt → VID02_000358.txt
# Renamed: VID_2_000359.txt → VID02_000359.txt
# Renamed: VID_2_000360.txt → VID02_000360.txt
# Renamed: VID_2_000361.txt → VID02_000361.txt
# Renamed: VID_2_000362.txt → VID02_000362.txt
# Renamed: VID_2_000363.txt → VID02_000363.txt
# Renamed: VID_2_000364.txt → VID02_000364.txt
# Renamed: VID_2_000365.txt → VID02_000365.txt
# Renamed: VID_2_000366.txt → VID02_000366.txt
# Renamed: VID_2_000367.txt → VID02_000367.txt
# Renamed: VID_2_000368.txt → VID02_000368.txt
# Renamed: VID_2_000369.txt → VID02_000369.txt
# Renamed: VID_2_000370.txt → VID02_000370.txt
# Renamed: VID_2_000371.txt → VID02_000371.txt
# Renamed: VID_2_000372.txt → VID02_000372.txt
# Renamed: VID_2_000373.txt → VID02_000373.txt
# Renamed: VID_2_000374.txt → VID02_000374.txt
# Renamed: VID_2_000375.txt → VID02_000375.txt
# Renamed: VID_2_000376.txt → VID02_000376.txt
# Renamed: VID_2_000377.txt → VID02_000377.txt
# Renamed: VID_2_000378.txt → VID02_000378.txt
# Renamed: VID_2_000379.txt → VID02_000379.txt
# Renamed: VID_2_000380.txt → VID02_000380.txt
# Renamed: VID_2_000381.txt → VID02_000381.txt
# Renamed: VID_2_000382.txt → VID02_000382.txt
# Renamed: VID_2_000383.txt → VID02_000383.txt
# Renamed: VID_2_000384.txt → VID02_000384.txt
# Renamed: VID_2_000385.txt → VID02_000385.txt
# Renamed: VID_2_000386.txt → VID02_000386.txt
# Renamed: VID_2_000387.txt → VID02_000387.txt
# Renamed: VID_2_000388.txt → VID02_000388.txt
# Renamed: VID_2_000389.txt → VID02_000389.txt
# Renamed: VID_2_000390.txt → VID02_000390.txt
# Renamed: VID_2_000391.txt → VID02_000391.txt
# Renamed: VID_2_000392.txt → VID02_000392.txt
# Renamed: VID_2_000393.txt → VID02_000393.txt
# Renamed: VID_2_000394.txt → VID02_000394.txt
# Renamed: VID_2_000395.txt → VID02_000395.txt
# Renamed: VID_2_000396.txt → VID02_000396.txt
# Renamed: VID_2_000397.txt → VID02_000397.txt
# Renamed: VID_2_000398.txt → VID02_000398.txt
# Renamed: VID_2_000399.txt → VID02_000399.txt
# Renamed: VID_2_000400.txt → VID02_000400.txt
# Renamed: VID_2_000401.txt → VID02_000401.txt
# Renamed: VID_2_000402.txt → VID02_000402.txt
# Renamed: VID_2_000403.txt → VID02_000403.txt
# Renamed: VID_2_000404.txt → VID02_000404.txt
# Renamed: VID_2_000405.txt → VID02_000405.txt
# Renamed: VID_2_000406.txt → VID02_000406.txt
# Renamed: VID_2_000407.txt → VID02_000407.txt
# Renamed: VID_2_000408.txt → VID02_000408.txt
# Renamed: VID_2_000409.txt → VID02_000409.txt
# Renamed: VID_2_000410.txt → VID02_000410.txt
# Renamed: VID_2_000411.txt → VID02_000411.txt
# Renamed: VID_2_000412.txt → VID02_000412.txt
# Renamed: VID_2_000413.txt → VID02_000413.txt
# Renamed: VID_2_000414.txt → VID02_000414.txt
# Renamed: VID_2_000415.txt → VID02_000415.txt
# Renamed: VID_2_000416.txt → VID02_000416.txt
# Renamed: VID_2_000417.txt → VID02_000417.txt
# Renamed: VID_2_000418.txt → VID02_000418.txt
# Renamed: VID_2_000419.txt → VID02_000419.txt
# Renamed: VID_2_000420.txt → VID02_000420.txt
# Renamed: VID_2_000421.txt → VID02_000421.txt
# Renamed: VID_2_000422.txt → VID02_000422.txt
# Renamed: VID_2_000423.txt → VID02_000423.txt
# Renamed: VID_2_000424.txt → VID02_000424.txt
# Renamed: VID_2_000425.txt → VID02_000425.txt
# Renamed: VID_2_000426.txt → VID02_000426.txt
# Renamed: VID_2_000427.txt → VID02_000427.txt
# Renamed: VID_2_000428.txt → VID02_000428.txt
# Renamed: VID_2_000429.txt → VID02_000429.txt
# Renamed: VID_2_000430.txt → VID02_000430.txt
# Renamed: VID_2_000431.txt → VID02_000431.txt
# Renamed: VID_2_000432.txt → VID02_000432.txt
# Renamed: VID_2_000433.txt → VID02_000433.txt
# Renamed: VID_2_000434.txt → VID02_000434.txt
# Renamed: VID_2_000435.txt → VID02_000435.txt
# Renamed: VID_2_000436.txt → VID02_000436.txt
# Renamed: VID_2_000437.txt → VID02_000437.txt
# Renamed: VID_2_000438.txt → VID02_000438.txt
# Renamed: VID_2_000439.txt → VID02_000439.txt
# Renamed: VID_2_000440.txt → VID02_000440.txt
# Renamed: VID_2_000441.txt → VID02_000441.txt
# Renamed: VID_2_000442.txt → VID02_000442.txt
# Renamed: VID_2_000443.txt → VID02_000443.txt
# Renamed: VID_2_000444.txt → VID02_000444.txt
# Renamed: VID_2_000445.txt → VID02_000445.txt
# Renamed: VID_2_000446.txt → VID02_000446.txt
# Renamed: VID_2_000447.txt → VID02_000447.txt
# Renamed: VID_2_000448.txt → VID02_000448.txt
# Renamed: VID_2_000449.txt → VID02_000449.txt
# Renamed: VID_2_000450.txt → VID02_000450.txt
# Renamed: VID_2_000451.txt → VID02_000451.txt
# Renamed: VID_2_000452.txt → VID02_000452.txt
# Renamed: VID_2_000453.txt → VID02_000453.txt
# Renamed: VID_2_000454.txt → VID02_000454.txt
# Renamed: VID_2_000455.txt → VID02_000455.txt
# Renamed: VID_2_000456.txt → VID02_000456.txt
# Renamed: VID_2_000457.txt → VID02_000457.txt
# Renamed: VID_2_000458.txt → VID02_000458.txt
# Renamed: VID_2_000459.txt → VID02_000459.txt
# Renamed: VID_2_000460.txt → VID02_000460.txt
# Renamed: VID_2_000461.txt → VID02_000461.txt
# Renamed: VID_2_000462.txt → VID02_000462.txt
# Renamed: VID_2_000463.txt → VID02_000463.txt
# Renamed: VID_2_000464.txt → VID02_000464.txt
# Renamed: VID_2_000465.txt → VID02_000465.txt
# Renamed: VID_2_000466.txt → VID02_000466.txt
# Renamed: VID_2_000467.txt → VID02_000467.txt
# Renamed: VID_2_000468.txt → VID02_000468.txt
# Renamed: VID_2_000469.txt → VID02_000469.txt
# Renamed: VID_2_000470.txt → VID02_000470.txt
# Renamed: VID_2_000471.txt → VID02_000471.txt
# Renamed: VID_2_000472.txt → VID02_000472.txt
# Renamed: VID_2_000473.txt → VID02_000473.txt
# Renamed: VID_2_000474.txt → VID02_000474.txt
# Renamed: VID_2_000475.txt → VID02_000475.txt
# Renamed: VID_2_000476.txt → VID02_000476.txt
# Renamed: VID_2_000477.txt → VID02_000477.txt
# Renamed: VID_2_000478.txt → VID02_000478.txt
# Renamed: VID_2_000479.txt → VID02_000479.txt
# Renamed: VID_2_000480.txt → VID02_000480.txt
# Renamed: VID_2_000481.txt → VID02_000481.txt
# Renamed: VID_2_000482.txt → VID02_000482.txt
# Renamed: VID_2_000483.txt → VID02_000483.txt
# Renamed: VID_2_000484.txt → VID02_000484.txt
# Renamed: VID_2_000485.txt → VID02_000485.txt
# Renamed: VID_2_000486.txt → VID02_000486.txt
# Renamed: VID_2_000487.txt → VID02_000487.txt
# Renamed: VID_2_000488.txt → VID02_000488.txt
# Renamed: VID_2_000489.txt → VID02_000489.txt
# Renamed: VID_2_000490.txt → VID02_000490.txt
# Renamed: VID_2_000491.txt → VID02_000491.txt
# Renamed: VID_2_000492.txt → VID02_000492.txt
# Renamed: VID_2_000493.txt → VID02_000493.txt
# Renamed: VID_2_000494.txt → VID02_000494.txt
# Renamed: VID_2_000495.txt → VID02_000495.txt
# Renamed: VID_2_000496.txt → VID02_000496.txt
# Renamed: VID_2_000497.txt → VID02_000497.txt
# Renamed: VID_2_000498.txt → VID02_000498.txt
# Renamed: VID_2_000499.txt → VID02_000499.txt
# Renamed: VID_2_000500.txt → VID02_000500.txt
# Renamed: VID_2_000501.txt → VID02_000501.txt
# Renamed: VID_2_000502.txt → VID02_000502.txt
# Renamed: VID_2_000503.txt → VID02_000503.txt
# Renamed: VID_2_000504.txt → VID02_000504.txt
# Renamed: VID_2_000505.txt → VID02_000505.txt
# Renamed: VID_2_000506.txt → VID02_000506.txt
# Renamed: VID_2_000507.txt → VID02_000507.txt
# Renamed: VID_2_000508.txt → VID02_000508.txt
# Renamed: VID_2_000509.txt → VID02_000509.txt
# Renamed: VID_2_000510.txt → VID02_000510.txt
# Renamed: VID_2_000511.txt → VID02_000511.txt
# Renamed: VID_2_000512.txt → VID02_000512.txt
# Renamed: VID_2_000513.txt → VID02_000513.txt
# Renamed: VID_2_000514.txt → VID02_000514.txt
# Renamed: VID_2_000515.txt → VID02_000515.txt
# Renamed: VID_2_000516.txt → VID02_000516.txt
# Renamed: VID_2_000517.txt → VID02_000517.txt
# Renamed: VID_2_000518.txt → VID02_000518.txt
# Renamed: VID_2_000519.txt → VID02_000519.txt
# Renamed: VID_2_000520.txt → VID02_000520.txt
# Renamed: VID_2_000521.txt → VID02_000521.txt
# Renamed: VID_2_000522.txt → VID02_000522.txt
# Renamed: VID_2_000523.txt → VID02_000523.txt
# Renamed: VID_2_000524.txt → VID02_000524.txt
# Renamed: VID_2_000525.txt → VID02_000525.txt
# Renamed: VID_2_000526.txt → VID02_000526.txt
# Renamed: VID_2_000527.txt → VID02_000527.txt
# Renamed: VID_2_000528.txt → VID02_000528.txt
# Renamed: VID_2_000529.txt → VID02_000529.txt
# Renamed: VID_2_000530.txt → VID02_000530.txt
# Renamed: VID_2_000531.txt → VID02_000531.txt
# Renamed: VID_2_000532.txt → VID02_000532.txt
# Renamed: VID_2_000533.txt → VID02_000533.txt
# Renamed: VID_2_000534.txt → VID02_000534.txt
# Renamed: VID_2_000535.txt → VID02_000535.txt
# Renamed: VID_2_000536.txt → VID02_000536.txt
# Renamed: VID_2_000537.txt → VID02_000537.txt
# Renamed: VID_2_000538.txt → VID02_000538.txt
# Renamed: VID_2_000539.txt → VID02_000539.txt
# Renamed: VID_2_000540.txt → VID02_000540.txt
# Renamed: VID_2_000541.txt → VID02_000541.txt
# Renamed: VID_2_000542.txt → VID02_000542.txt
# Renamed: VID_2_000543.txt → VID02_000543.txt
# Renamed: VID_2_000544.txt → VID02_000544.txt
# Renamed: VID_2_000545.txt → VID02_000545.txt
# Renamed: VID_2_000546.txt → VID02_000546.txt
# Renamed: VID_2_000547.txt → VID02_000547.txt
# Renamed: VID_2_000548.txt → VID02_000548.txt
# Renamed: VID_2_000549.txt → VID02_000549.txt
# Renamed: VID_2_000550.txt → VID02_000550.txt
# Renamed: VID_2_000551.txt → VID02_000551.txt
# Renamed: VID_2_000552.txt → VID02_000552.txt
# Renamed: VID_2_000553.txt → VID02_000553.txt
# Renamed: VID_2_000554.txt → VID02_000554.txt
# Renamed: VID_2_000555.txt → VID02_000555.txt
# Renamed: VID_2_000556.txt → VID02_000556.txt
# Renamed: VID_2_000557.txt → VID02_000557.txt
# Renamed: VID_2_000558.txt → VID02_000558.txt
# Renamed: VID_2_000559.txt → VID02_000559.txt
# Renamed: VID_2_000560.txt → VID02_000560.txt
# Renamed: VID_2_000561.txt → VID02_000561.txt
# Renamed: VID_2_000562.txt → VID02_000562.txt
# Renamed: VID_2_000563.txt → VID02_000563.txt
# Renamed: VID_2_000564.txt → VID02_000564.txt
# Renamed: VID_2_000565.txt → VID02_000565.txt
# Renamed: VID_2_000566.txt → VID02_000566.txt
# Renamed: VID_2_000567.txt → VID02_000567.txt
# Renamed: VID_2_000568.txt → VID02_000568.txt
# Renamed: VID_2_000569.txt → VID02_000569.txt
# Renamed: VID_2_000570.txt → VID02_000570.txt
# Renamed: VID_2_000571.txt → VID02_000571.txt
# Renamed: VID_2_000572.txt → VID02_000572.txt
# Renamed: VID_2_000573.txt → VID02_000573.txt
# Renamed: VID_2_000574.txt → VID02_000574.txt
# Renamed: VID_2_000575.txt → VID02_000575.txt
# Renamed: VID_2_000576.txt → VID02_000576.txt
# Renamed: VID_2_000577.txt → VID02_000577.txt
# Renamed: VID_2_000578.txt → VID02_000578.txt
# Renamed: VID_2_000579.txt → VID02_000579.txt
# Renamed: VID_2_000580.txt → VID02_000580.txt
# Renamed: VID_2_000581.txt → VID02_000581.txt
# Renamed: VID_2_000582.txt → VID02_000582.txt
# Renamed: VID_2_000583.txt → VID02_000583.txt
# Renamed: VID_2_000584.txt → VID02_000584.txt
# Renamed: VID_2_000585.txt → VID02_000585.txt
# Renamed: VID_2_000586.txt → VID02_000586.txt
# Renamed: VID_2_000587.txt → VID02_000587.txt
# Renamed: VID_2_000588.txt → VID02_000588.txt
# Renamed: VID_2_000589.txt → VID02_000589.txt
# Renamed: VID_2_000590.txt → VID02_000590.txt
# Renamed: VID_2_000591.txt → VID02_000591.txt
# Renamed: VID_2_000592.txt → VID02_000592.txt
# Renamed: VID_2_000593.txt → VID02_000593.txt
# Renamed: VID_2_000594.txt → VID02_000594.txt
# Renamed: VID_2_000595.txt → VID02_000595.txt
# Renamed: VID_2_000596.txt → VID02_000596.txt
# Renamed: VID_2_000597.txt → VID02_000597.txt
# Renamed: VID_2_000598.txt → VID02_000598.txt
# Renamed: VID_2_000599.txt → VID02_000599.txt
# Renamed: VID_2_000600.txt → VID02_000600.txt
# Renamed: VID_2_000601.txt → VID02_000601.txt
# Renamed: VID_2_000602.txt → VID02_000602.txt
# Renamed: VID_2_000603.txt → VID02_000603.txt
# Renamed: VID_2_000604.txt → VID02_000604.txt
# Renamed: VID_2_000605.txt → VID02_000605.txt
# Renamed: VID_2_000606.txt → VID02_000606.txt
# Renamed: VID_2_000607.txt → VID02_000607.txt
# Renamed: VID_2_000608.txt → VID02_000608.txt
# Renamed: VID_2_000609.txt → VID02_000609.txt
# Renamed: VID_2_000610.txt → VID02_000610.txt
# Renamed: VID_2_000611.txt → VID02_000611.txt
# Renamed: VID_2_000612.txt → VID02_000612.txt
# Renamed: VID_2_000613.txt → VID02_000613.txt
# Renamed: VID_2_000614.txt → VID02_000614.txt
# Renamed: VID_2_000615.txt → VID02_000615.txt
# Renamed: VID_2_000616.txt → VID02_000616.txt
# Renamed: VID_2_000617.txt → VID02_000617.txt
# Renamed: VID_2_000618.txt → VID02_000618.txt
# Renamed: VID_2_000619.txt → VID02_000619.txt
# Renamed: VID_2_000620.txt → VID02_000620.txt
# Renamed: VID_2_000621.txt → VID02_000621.txt
# Renamed: VID_2_000622.txt → VID02_000622.txt
# Renamed: VID_2_000623.txt → VID02_000623.txt
# Renamed: VID_2_000624.txt → VID02_000624.txt
# Renamed: VID_2_000625.txt → VID02_000625.txt
# Renamed: VID_2_000626.txt → VID02_000626.txt
# Renamed: VID_2_000627.txt → VID02_000627.txt
# Renamed: VID_2_000628.txt → VID02_000628.txt
# Renamed: VID_2_000629.txt → VID02_000629.txt
# Renamed: VID_2_000630.txt → VID02_000630.txt
# Renamed: VID_2_000631.txt → VID02_000631.txt
# Renamed: VID_2_000632.txt → VID02_000632.txt
# Renamed: VID_2_000633.txt → VID02_000633.txt
# Renamed: VID_2_000634.txt → VID02_000634.txt
# Renamed: VID_2_000635.txt → VID02_000635.txt
# Renamed: VID_2_000636.txt → VID02_000636.txt
# Renamed: VID_2_000637.txt → VID02_000637.txt
# Renamed: VID_2_000638.txt → VID02_000638.txt
# Renamed: VID_2_000639.txt → VID02_000639.txt
# Renamed: VID_2_000640.txt → VID02_000640.txt
# Renamed: VID_2_000641.txt → VID02_000641.txt
# Renamed: VID_2_000642.txt → VID02_000642.txt
# Renamed: VID_2_000643.txt → VID02_000643.txt
# Renamed: VID_2_000644.txt → VID02_000644.txt
# Renamed: VID_2_000645.txt → VID02_000645.txt
# Renamed: VID_2_000646.txt → VID02_000646.txt
# Renamed: VID_2_000647.txt → VID02_000647.txt
# Renamed: VID_2_000648.txt → VID02_000648.txt
# Renamed: VID_2_000649.txt → VID02_000649.txt
# Renamed: VID_2_000650.txt → VID02_000650.txt
# Renamed: VID_2_000651.txt → VID02_000651.txt
# Renamed: VID_2_000652.txt → VID02_000652.txt
# Renamed: VID_2_000653.txt → VID02_000653.txt
# Renamed: VID_2_000654.txt → VID02_000654.txt
# Renamed: VID_2_000655.txt → VID02_000655.txt
# Renamed: VID_2_000656.txt → VID02_000656.txt
# Renamed: VID_2_000657.txt → VID02_000657.txt
# Renamed: VID_2_000658.txt → VID02_000658.txt
# Renamed: VID_2_000659.txt → VID02_000659.txt
# Renamed: VID_2_000660.txt → VID02_000660.txt
# Renamed: VID_2_000661.txt → VID02_000661.txt
# Renamed: VID_2_000662.txt → VID02_000662.txt
# Renamed: VID_2_000663.txt → VID02_000663.txt
# Renamed: VID_2_000664.txt → VID02_000664.txt
# Renamed: VID_2_000665.txt → VID02_000665.txt
# Renamed: VID_2_000666.txt → VID02_000666.txt
# Renamed: VID_2_000667.txt → VID02_000667.txt
# Renamed: VID_2_000668.txt → VID02_000668.txt
# Renamed: VID_2_000669.txt → VID02_000669.txt
# Renamed: VID_2_000670.txt → VID02_000670.txt
# Renamed: VID_2_000671.txt → VID02_000671.txt
# Renamed: VID_2_000672.txt → VID02_000672.txt
# Renamed: VID_2_000673.txt → VID02_000673.txt
# Renamed: VID_2_000674.txt → VID02_000674.txt
# Renamed: VID_2_000675.txt → VID02_000675.txt
# Renamed: VID_2_000676.txt → VID02_000676.txt
# Renamed: VID_2_000677.txt → VID02_000677.txt
# Renamed: VID_2_000678.txt → VID02_000678.txt
# Renamed: VID_2_000679.txt → VID02_000679.txt
# Renamed: VID_2_000680.txt → VID02_000680.txt
# Renamed: VID_2_000681.txt → VID02_000681.txt
# Renamed: VID_2_000682.txt → VID02_000682.txt
# Renamed: VID_2_000683.txt → VID02_000683.txt
# Renamed: VID_2_000684.txt → VID02_000684.txt
# Renamed: VID_2_000685.txt → VID02_000685.txt
# Renamed: VID_2_000686.txt → VID02_000686.txt
# Renamed: VID_2_000687.txt → VID02_000687.txt
# Renamed: VID_2_000688.txt → VID02_000688.txt
# Renamed: VID_2_000689.txt → VID02_000689.txt
# Renamed: VID_2_000690.txt → VID02_000690.txt
# Renamed: VID_2_000691.txt → VID02_000691.txt
# Renamed: VID_2_000692.txt → VID02_000692.txt
# Renamed: VID_2_000693.txt → VID02_000693.txt
# Renamed: VID_2_000694.txt → VID02_000694.txt
# Renamed: VID_2_000695.txt → VID02_000695.txt
# Renamed: VID_2_000696.txt → VID02_000696.txt
# Renamed: VID_2_000697.txt → VID02_000697.txt
# Renamed: VID_2_000698.txt → VID02_000698.txt
# Renamed: VID_2_000699.txt → VID02_000699.txt
# Renamed: VID_2_000700.txt → VID02_000700.txt
# Renamed: VID_2_000701.txt → VID02_000701.txt
# Renamed: VID_2_000702.txt → VID02_000702.txt
# Renamed: VID_2_000703.txt → VID02_000703.txt
# Renamed: VID_2_000704.txt → VID02_000704.txt
# Renamed: VID_2_000705.txt → VID02_000705.txt
# Renamed: VID_2_000706.txt → VID02_000706.txt
# Renamed: VID_2_000707.txt → VID02_000707.txt
# Renamed: VID_2_000708.txt → VID02_000708.txt
# Renamed: VID_2_000709.txt → VID02_000709.txt
# Renamed: VID_2_000710.txt → VID02_000710.txt
# Renamed: VID_2_000711.txt → VID02_000711.txt
# Renamed: VID_2_000712.txt → VID02_000712.txt
# Renamed: VID_2_000713.txt → VID02_000713.txt
# Renamed: VID_2_000714.txt → VID02_000714.txt
# Renamed: VID_2_000715.txt → VID02_000715.txt
# Renamed: VID_2_000716.txt → VID02_000716.txt
# Renamed: VID_2_000717.txt → VID02_000717.txt
# Renamed: VID_2_000718.txt → VID02_000718.txt
# Renamed: VID_2_000719.txt → VID02_000719.txt
# Renamed: VID_2_000720.txt → VID02_000720.txt
# Renamed: VID_2_000721.txt → VID02_000721.txt
# Renamed: VID_2_000722.txt → VID02_000722.txt
# Renamed: VID_2_000723.txt → VID02_000723.txt
# Renamed: VID_2_000724.txt → VID02_000724.txt
# Renamed: VID_2_000725.txt → VID02_000725.txt
# Renamed: VID_2_000726.txt → VID02_000726.txt
# Renamed: VID_2_000727.txt → VID02_000727.txt
# Renamed: VID_2_000728.txt → VID02_000728.txt
# Renamed: VID_2_000729.txt → VID02_000729.txt
# Renamed: VID_2_000730.txt → VID02_000730.txt
# Renamed: VID_2_000731.txt → VID02_000731.txt
# Renamed: VID_2_000732.txt → VID02_000732.txt
# Renamed: VID_2_000733.txt → VID02_000733.txt
# Renamed: VID_2_000734.txt → VID02_000734.txt
# Renamed: VID_2_000735.txt → VID02_000735.txt
# Renamed: VID_2_000736.txt → VID02_000736.txt
# Renamed: VID_2_000737.txt → VID02_000737.txt
# Renamed: VID_2_000738.txt → VID02_000738.txt
# Renamed: VID_2_000739.txt → VID02_000739.txt
# Renamed: VID_2_000740.txt → VID02_000740.txt
# Renamed: VID_2_000741.txt → VID02_000741.txt
# Renamed: VID_2_000742.txt → VID02_000742.txt
# Renamed: VID_2_000743.txt → VID02_000743.txt
# Renamed: VID_2_000744.txt → VID02_000744.txt
# Renamed: VID_2_000745.txt → VID02_000745.txt
# Renamed: VID_2_000746.txt → VID02_000746.txt
# Renamed: VID_2_000747.txt → VID02_000747.txt
# Renamed: VID_2_000748.txt → VID02_000748.txt
# Renamed: VID_2_000749.txt → VID02_000749.txt
# Renamed: VID_2_000750.txt → VID02_000750.txt
# Renamed: VID_2_000751.txt → VID02_000751.txt
# Renamed: VID_2_000752.txt → VID02_000752.txt
# Renamed: VID_2_000753.txt → VID02_000753.txt
# Renamed: VID_2_000754.txt → VID02_000754.txt
# Renamed: VID_2_000755.txt → VID02_000755.txt
# Renamed: VID_2_000756.txt → VID02_000756.txt
# Renamed: VID_2_000757.txt → VID02_000757.txt
# Renamed: VID_2_000758.txt → VID02_000758.txt
# Renamed: VID_2_000759.txt → VID02_000759.txt
# Renamed: VID_2_000760.txt → VID02_000760.txt
# Renamed: VID_2_000761.txt → VID02_000761.txt
# Renamed: VID_2_000762.txt → VID02_000762.txt
# Renamed: VID_2_000763.txt → VID02_000763.txt
# Renamed: VID_2_000764.txt → VID02_000764.txt
# Renamed: VID_2_000765.txt → VID02_000765.txt
# Renamed: VID_2_000766.txt → VID02_000766.txt
# Renamed: VID_2_000767.txt → VID02_000767.txt
# Renamed: VID_2_000768.txt → VID02_000768.txt
# Renamed: VID_2_000769.txt → VID02_000769.txt
# Renamed: VID_2_000770.txt → VID02_000770.txt
# Renamed: VID_2_000771.txt → VID02_000771.txt
# Renamed: VID_2_000772.txt → VID02_000772.txt
# Renamed: VID_2_000773.txt → VID02_000773.txt
# Renamed: VID_2_000774.txt → VID02_000774.txt
# Renamed: VID_2_000775.txt → VID02_000775.txt
# Renamed: VID_2_000776.txt → VID02_000776.txt
# Renamed: VID_2_000777.txt → VID02_000777.txt
# Renamed: VID_2_000778.txt → VID02_000778.txt
# Renamed: VID_2_000779.txt → VID02_000779.txt
# Renamed: VID_2_000780.txt → VID02_000780.txt
# Renamed: VID_2_000781.txt → VID02_000781.txt
# Renamed: VID_2_000782.txt → VID02_000782.txt
# Renamed: VID_2_000783.txt → VID02_000783.txt
# Renamed: VID_2_000784.txt → VID02_000784.txt
# Renamed: VID_2_000785.txt → VID02_000785.txt
# Renamed: VID_2_000786.txt → VID02_000786.txt
# Renamed: VID_2_000787.txt → VID02_000787.txt
# Renamed: VID_2_000788.txt → VID02_000788.txt
# Renamed: VID_2_000789.txt → VID02_000789.txt
# Renamed: VID_2_000790.txt → VID02_000790.txt
# Renamed: VID_2_000791.txt → VID02_000791.txt
# Renamed: VID_2_000792.txt → VID02_000792.txt
# Renamed: VID_2_000793.txt → VID02_000793.txt
# Renamed: VID_2_000794.txt → VID02_000794.txt
# Renamed: VID_2_000795.txt → VID02_000795.txt
# Renamed: VID_2_000796.txt → VID02_000796.txt
# Renamed: VID_2_000797.txt → VID02_000797.txt
# Renamed: VID_2_000798.txt → VID02_000798.txt
# Renamed: VID_2_000799.txt → VID02_000799.txt
# Renamed: VID_2_000800.txt → VID02_000800.txt
# Renamed: VID_2_000801.txt → VID02_000801.txt
# Renamed: VID_2_000802.txt → VID02_000802.txt
# Renamed: VID_2_000803.txt → VID02_000803.txt
# Renamed: VID_2_000804.txt → VID02_000804.txt
# Renamed: VID_2_000805.txt → VID02_000805.txt
# Renamed: VID_2_000806.txt → VID02_000806.txt
# Renamed: VID_2_000807.txt → VID02_000807.txt
# Renamed: VID_2_000808.txt → VID02_000808.txt
# Renamed: VID_2_000809.txt → VID02_000809.txt
# Renamed: VID_2_000810.txt → VID02_000810.txt
# Renamed: VID_2_000811.txt → VID02_000811.txt
# Renamed: VID_2_000812.txt → VID02_000812.txt
# Renamed: VID_2_000813.txt → VID02_000813.txt
# Renamed: VID_2_000814.txt → VID02_000814.txt
# Renamed: VID_2_000815.txt → VID02_000815.txt
# Renamed: VID_2_000816.txt → VID02_000816.txt
# Renamed: VID_2_000817.txt → VID02_000817.txt
# Renamed: VID_2_000818.txt → VID02_000818.txt
# Renamed: VID_2_000819.txt → VID02_000819.txt
# Renamed: VID_2_000820.txt → VID02_000820.txt
# Renamed: VID_2_000821.txt → VID02_000821.txt
# Renamed: VID_2_000822.txt → VID02_000822.txt
# Renamed: VID_2_000823.txt → VID02_000823.txt
# Renamed: VID_2_000824.txt → VID02_000824.txt
# Renamed: VID_2_000825.txt → VID02_000825.txt
# Renamed: VID_2_000826.txt → VID02_000826.txt
# Renamed: VID_2_000827.txt → VID02_000827.txt
# Renamed: VID_2_000828.txt → VID02_000828.txt
# Renamed: VID_2_000829.txt → VID02_000829.txt
# Renamed: VID_2_000830.txt → VID02_000830.txt
# Renamed: VID_2_000831.txt → VID02_000831.txt
# Renamed: VID_2_000832.txt → VID02_000832.txt
# Renamed: VID_2_000833.txt → VID02_000833.txt
# Renamed: VID_2_000834.txt → VID02_000834.txt
# Renamed: VID_2_000835.txt → VID02_000835.txt
# Renamed: VID_2_000836.txt → VID02_000836.txt
# Renamed: VID_2_000837.txt → VID02_000837.txt
# Renamed: VID_2_000838.txt → VID02_000838.txt
# Renamed: VID_2_000839.txt → VID02_000839.txt
# Renamed: VID_2_000840.txt → VID02_000840.txt
# Renamed: VID_2_000841.txt → VID02_000841.txt
# Renamed: VID_2_000842.txt → VID02_000842.txt
# Renamed: VID_2_000843.txt → VID02_000843.txt
# Renamed: VID_2_000844.txt → VID02_000844.txt
# Renamed: VID_2_000845.txt → VID02_000845.txt
# Renamed: VID_2_000846.txt → VID02_000846.txt
# Renamed: VID_2_000847.txt → VID02_000847.txt
# Renamed: VID_2_000848.txt → VID02_000848.txt
# Renamed: VID_2_000849.txt → VID02_000849.txt
# Renamed: VID_2_000850.txt → VID02_000850.txt
# Renamed: VID_2_000851.txt → VID02_000851.txt
# Renamed: VID_2_000852.txt → VID02_000852.txt
# Renamed: VID_2_000853.txt → VID02_000853.txt
# Renamed: VID_2_000854.txt → VID02_000854.txt
# Renamed: VID_2_000855.txt → VID02_000855.txt
# Renamed: VID_2_000856.txt → VID02_000856.txt
# Renamed: VID_2_000857.txt → VID02_000857.txt
# Renamed: VID_2_000858.txt → VID02_000858.txt
# Renamed: VID_2_000859.txt → VID02_000859.txt
# Renamed: VID_2_000860.txt → VID02_000860.txt
# Renamed: VID_2_000861.txt → VID02_000861.txt
# Renamed: VID_2_000862.txt → VID02_000862.txt
# Renamed: VID_2_000863.txt → VID02_000863.txt
# Renamed: VID_2_000864.txt → VID02_000864.txt
# Renamed: VID_2_000865.txt → VID02_000865.txt
# Renamed: VID_2_000866.txt → VID02_000866.txt
# Renamed: VID_2_000867.txt → VID02_000867.txt
# Renamed: VID_2_000868.txt → VID02_000868.txt
# Renamed: VID_2_000869.txt → VID02_000869.txt
# Renamed: VID_2_000870.txt → VID02_000870.txt
# Renamed: VID_2_000871.txt → VID02_000871.txt
# Renamed: VID_2_000872.txt → VID02_000872.txt
# Renamed: VID_2_000873.txt → VID02_000873.txt
# Renamed: VID_2_000874.txt → VID02_000874.txt
# Renamed: VID_2_000875.txt → VID02_000875.txt
# Renamed: VID_2_000876.txt → VID02_000876.txt
# Renamed: VID_2_000877.txt → VID02_000877.txt
# Renamed: VID_2_000878.txt → VID02_000878.txt
# Renamed: VID_2_000879.txt → VID02_000879.txt
# Renamed: VID_2_000880.txt → VID02_000880.txt
# Renamed: VID_2_000881.txt → VID02_000881.txt
# Renamed: VID_2_000882.txt → VID02_000882.txt
# Renamed: VID_2_000883.txt → VID02_000883.txt
# Renamed: VID_2_000884.txt → VID02_000884.txt
# Renamed: VID_2_000885.txt → VID02_000885.txt
# Renamed: VID_2_000886.txt → VID02_000886.txt
# Renamed: VID_2_000887.txt → VID02_000887.txt
# Renamed: VID_2_000888.txt → VID02_000888.txt
# Renamed: VID_2_000889.txt → VID02_000889.txt
# Renamed: VID_2_000890.txt → VID02_000890.txt
# Renamed: VID_2_000891.txt → VID02_000891.txt
# Renamed: VID_2_000892.txt → VID02_000892.txt
# Renamed: VID_2_000893.txt → VID02_000893.txt
# Renamed: VID_2_000894.txt → VID02_000894.txt
# Renamed: VID_2_000895.txt → VID02_000895.txt
# Renamed: VID_2_000896.txt → VID02_000896.txt
# Renamed: VID_2_000897.txt → VID02_000897.txt
# Renamed: VID_2_000898.txt → VID02_000898.txt
# Renamed: VID_2_000899.txt → VID02_000899.txt
# Renamed: VID_2_000900.txt → VID02_000900.txt
# Renamed: VID_2_000901.txt → VID02_000901.txt
# Renamed: VID_2_000902.txt → VID02_000902.txt
# Renamed: VID_2_000903.txt → VID02_000903.txt
# Renamed: VID_2_000904.txt → VID02_000904.txt
# Renamed: VID_2_000905.txt → VID02_000905.txt
# Renamed: VID_2_000906.txt → VID02_000906.txt
# Renamed: VID_2_000907.txt → VID02_000907.txt
# Renamed: VID_2_000908.txt → VID02_000908.txt
# Renamed: VID_2_000909.txt → VID02_000909.txt
# Renamed: VID_2_000910.txt → VID02_000910.txt
# Renamed: VID_2_000911.txt → VID02_000911.txt
# Renamed: VID_2_000912.txt → VID02_000912.txt
# Renamed: VID_2_000913.txt → VID02_000913.txt
# Renamed: VID_2_000914.txt → VID02_000914.txt
# Renamed: VID_2_000915.txt → VID02_000915.txt
# Renamed: VID_2_000916.txt → VID02_000916.txt
# Renamed: VID_2_000917.txt → VID02_000917.txt
# Renamed: VID_2_000918.txt → VID02_000918.txt
# Renamed: VID_2_000919.txt → VID02_000919.txt
# Renamed: VID_2_000920.txt → VID02_000920.txt
# Renamed: VID_2_000921.txt → VID02_000921.txt
# Renamed: VID_2_000922.txt → VID02_000922.txt
# Renamed: VID_2_000923.txt → VID02_000923.txt
# Renamed: VID_2_000924.txt → VID02_000924.txt
# Renamed: VID_2_000925.txt → VID02_000925.txt
# Renamed: VID_2_000926.txt → VID02_000926.txt
# Renamed: VID_2_000927.txt → VID02_000927.txt
# Renamed: VID_2_000928.txt → VID02_000928.txt
# Renamed: VID_2_000929.txt → VID02_000929.txt
# Renamed: VID_2_000930.txt → VID02_000930.txt
# Renamed: VID_2_000931.txt → VID02_000931.txt
# Renamed: VID_2_000932.txt → VID02_000932.txt
# Renamed: VID_2_000933.txt → VID02_000933.txt
# Renamed: VID_2_000934.txt → VID02_000934.txt
# Renamed: VID_2_000935.txt → VID02_000935.txt
# Renamed: VID_2_000936.txt → VID02_000936.txt
# Renamed: VID_2_000937.txt → VID02_000937.txt
# Renamed: VID_2_000938.txt → VID02_000938.txt
# Renamed: VID_2_000939.txt → VID02_000939.txt
# Renamed: VID_2_000940.txt → VID02_000940.txt
# Renamed: VID_2_000941.txt → VID02_000941.txt
# Renamed: VID_2_000942.txt → VID02_000942.txt
# Renamed: VID_2_000943.txt → VID02_000943.txt
# Renamed: VID_2_000944.txt → VID02_000944.txt
# Renamed: VID_2_000945.txt → VID02_000945.txt
# Renamed: VID_2_000946.txt → VID02_000946.txt
# Renamed: VID_2_000947.txt → VID02_000947.txt
# Renamed: VID_2_000948.txt → VID02_000948.txt
# Renamed: VID_2_000949.txt → VID02_000949.txt
# Renamed: VID_2_000950.txt → VID02_000950.txt
# Renamed: VID_2_000951.txt → VID02_000951.txt
# Renamed: VID_2_000952.txt → VID02_000952.txt
# Renamed: VID_2_000953.txt → VID02_000953.txt
# Renamed: VID_2_000954.txt → VID02_000954.txt
# Renamed: VID_2_000955.txt → VID02_000955.txt
# Renamed: VID_2_000956.txt → VID02_000956.txt
# Renamed: VID_2_000957.txt → VID02_000957.txt
# Renamed: VID_2_000958.txt → VID02_000958.txt
# Renamed: VID_2_000959.txt → VID02_000959.txt
# Renamed: VID_2_000960.txt → VID02_000960.txt
# Renamed: VID_2_000961.txt → VID02_000961.txt
# Renamed: VID_2_000962.txt → VID02_000962.txt
# Renamed: VID_2_000963.txt → VID02_000963.txt
# Renamed: VID_2_000964.txt → VID02_000964.txt
# Renamed: VID_2_000965.txt → VID02_000965.txt
# Renamed: VID_2_000966.txt → VID02_000966.txt
# Renamed: VID_2_000967.txt → VID02_000967.txt
# Renamed: VID_2_000968.txt → VID02_000968.txt
# Renamed: VID_2_000969.txt → VID02_000969.txt
# Renamed: VID_2_000970.txt → VID02_000970.txt
# Renamed: VID_2_000971.txt → VID02_000971.txt
# Renamed: VID_2_000972.txt → VID02_000972.txt
# Renamed: VID_2_000973.txt → VID02_000973.txt
# Renamed: VID_2_000974.txt → VID02_000974.txt
# Renamed: VID_2_000975.txt → VID02_000975.txt
# Renamed: VID_2_000976.txt → VID02_000976.txt
# Renamed: VID_2_000977.txt → VID02_000977.txt
# Renamed: VID_2_000978.txt → VID02_000978.txt
# Renamed: VID_2_000979.txt → VID02_000979.txt
# Renamed: VID_2_000980.txt → VID02_000980.txt
# Renamed: VID_2_000981.txt → VID02_000981.txt
# Renamed: VID_2_000982.txt → VID02_000982.txt
# Renamed: VID_2_000983.txt → VID02_000983.txt
# Renamed: VID_2_000984.txt → VID02_000984.txt
# Renamed: VID_2_000985.txt → VID02_000985.txt
# Renamed: VID_2_000986.txt → VID02_000986.txt
# Renamed: VID_2_000987.txt → VID02_000987.txt
# Renamed: VID_2_000988.txt → VID02_000988.txt
# Renamed: VID_2_000989.txt → VID02_000989.txt
# Renamed: VID_2_000990.txt → VID02_000990.txt
# Renamed: VID_2_000991.txt → VID02_000991.txt
# Renamed: VID_2_000992.txt → VID02_000992.txt
# Renamed: VID_2_000993.txt → VID02_000993.txt
# Renamed: VID_2_000994.txt → VID02_000994.txt
# Renamed: VID_2_000995.txt → VID02_000995.txt
# Renamed: VID_2_000996.txt → VID02_000996.txt
# Renamed: VID_2_000997.txt → VID02_000997.txt
# Renamed: VID_2_000998.txt → VID02_000998.txt
# Renamed: VID_2_000999.txt → VID02_000999.txt
# Renamed: VID_2_001000.txt → VID02_001000.txt
# Renamed: VID_2_001001.txt → VID02_001001.txt
# Renamed: VID_2_001002.txt → VID02_001002.txt
# Renamed: VID_2_001003.txt → VID02_001003.txt
# Renamed: VID_2_001004.txt → VID02_001004.txt
# Renamed: VID_2_001005.txt → VID02_001005.txt
# Renamed: VID_2_001006.txt → VID02_001006.txt
# Renamed: VID_2_001007.txt → VID02_001007.txt
# Renamed: VID_2_001008.txt → VID02_001008.txt
# Renamed: VID_2_001009.txt → VID02_001009.txt
# Renamed: VID_2_001010.txt → VID02_001010.txt
# Renamed: VID_2_001011.txt → VID02_001011.txt
# Renamed: VID_2_001012.txt → VID02_001012.txt
# Renamed: VID_2_001013.txt → VID02_001013.txt
# Renamed: VID_2_001014.txt → VID02_001014.txt
# Renamed: VID_2_001015.txt → VID02_001015.txt
# Renamed: VID_2_001016.txt → VID02_001016.txt
# Renamed: VID_2_001017.txt → VID02_001017.txt
# Renamed: VID_2_001018.txt → VID02_001018.txt
# Renamed: VID_2_001019.txt → VID02_001019.txt
# Renamed: VID_2_001020.txt → VID02_001020.txt
# Renamed: VID_2_001021.txt → VID02_001021.txt
# Renamed: VID_2_001022.txt → VID02_001022.txt
# Renamed: VID_2_001023.txt → VID02_001023.txt
# Renamed: VID_2_001024.txt → VID02_001024.txt
# Renamed: VID_2_001025.txt → VID02_001025.txt
# Renamed: VID_2_001026.txt → VID02_001026.txt
# Renamed: VID_2_001027.txt → VID02_001027.txt
# Renamed: VID_2_001028.txt → VID02_001028.txt
# Renamed: VID_2_001029.txt → VID02_001029.txt
# Renamed: VID_2_001030.txt → VID02_001030.txt
# Renamed: VID_2_001031.txt → VID02_001031.txt
# Renamed: VID_2_001032.txt → VID02_001032.txt
# Renamed: VID_2_001033.txt → VID02_001033.txt
# Renamed: VID_2_001034.txt → VID02_001034.txt
# Renamed: VID_2_001035.txt → VID02_001035.txt
# Renamed: VID_2_001036.txt → VID02_001036.txt
# Renamed: VID_2_001037.txt → VID02_001037.txt
# Renamed: VID_2_001038.txt → VID02_001038.txt
# Renamed: VID_2_001039.txt → VID02_001039.txt
# Renamed: VID_2_001040.txt → VID02_001040.txt
# Renamed: VID_2_001041.txt → VID02_001041.txt
# Renamed: VID_2_001042.txt → VID02_001042.txt
# Renamed: VID_2_001043.txt → VID02_001043.txt
# Renamed: VID_2_001044.txt → VID02_001044.txt
# Renamed: VID_2_001045.txt → VID02_001045.txt
# Renamed: VID_2_001046.txt → VID02_001046.txt
# Renamed: VID_2_001047.txt → VID02_001047.txt
# Renamed: VID_2_001048.txt → VID02_001048.txt
# Renamed: VID_2_001049.txt → VID02_001049.txt
# Renamed: VID_2_001050.txt → VID02_001050.txt
# Renamed: VID_2_001051.txt → VID02_001051.txt
# Renamed: VID_2_001052.txt → VID02_001052.txt
# Renamed: VID_2_001053.txt → VID02_001053.txt
# Renamed: VID_2_001054.txt → VID02_001054.txt
# Renamed: VID_2_001055.txt → VID02_001055.txt
# Renamed: VID_2_001056.txt → VID02_001056.txt
# Renamed: VID_2_001057.txt → VID02_001057.txt
# Renamed: VID_2_001058.txt → VID02_001058.txt
# Renamed: VID_2_001059.txt → VID02_001059.txt
# Renamed: VID_2_001060.txt → VID02_001060.txt
# Renamed: VID_2_001061.txt → VID02_001061.txt
# Renamed: VID_2_001062.txt → VID02_001062.txt
# Renamed: VID_2_001063.txt → VID02_001063.txt
# Renamed: VID_2_001064.txt → VID02_001064.txt
# Renamed: VID_2_001065.txt → VID02_001065.txt
# ...
# Renamed: VID_10_001403.txt → VID10_001403.txt
# Renamed: VID_10_001404.txt → VID10_001404.txt
# Renamed: VID_10_001405.txt → VID10_001405.txt
# Renamed: VID_10_001406.txt → VID10_001406.txt
# Renamed: VID_10_001407.txt → VID10_001407.txt
# Renamed: VID_10_001408.txt → VID10_001408.txt
# Renamed: VID_10_001409.txt → VID10_001409.txt
# Renamed: VID_10_001410.txt → VID10_001410.txt
# Renamed: VID_10_001411.txt → VID10_001411.txt
# Renamed: VID_10_001412.txt → VID10_001412.txt
# Renamed: VID_10_001413.txt → VID10_001413.txt
# Renamed: VID_10_001414.txt → VID10_001414.txt
# Renamed: VID_10_001415.txt → VID10_001415.txt
# Renamed: VID_10_001416.txt → VID10_001416.txt
# Renamed: VID_10_001417.txt → VID10_001417.txt
# Renamed: VID_10_001418.txt → VID10_001418.txt
# Renamed: VID_10_001419.txt → VID10_001419.txt
# Renamed: VID_10_001420.txt → VID10_001420.txt
# Renamed: VID_10_001421.txt → VID10_001421.txt
# Renamed: VID_10_001422.txt → VID10_001422.txt
# Renamed: VID_10_001423.txt → VID10_001423.txt
# Renamed: VID_10_001424.txt → VID10_001424.txt
# Renamed: VID_10_001425.txt → VID10_001425.txt
# Renamed: VID_10_001426.txt → VID10_001426.txt
# Renamed: VID_10_001427.txt → VID10_001427.txt
# Renamed: VID_10_001428.txt → VID10_001428.txt
# Renamed: VID_10_001429.txt → VID10_001429.txt
# Renamed: VID_10_001430.txt → VID10_001430.txt
# Renamed: VID_10_001431.txt → VID10_001431.txt
# Renamed: VID_10_001432.txt → VID10_001432.txt
# Renamed: VID_10_001433.txt → VID10_001433.txt
# Renamed: VID_10_001434.txt → VID10_001434.txt
# Renamed: VID_10_001435.txt → VID10_001435.txt
# Renamed: VID_10_001436.txt → VID10_001436.txt
# Renamed: VID_10_001437.txt → VID10_001437.txt
# Renamed: VID_10_001438.txt → VID10_001438.txt
# Renamed: VID_10_001439.txt → VID10_001439.txt
# Renamed: VID_10_001440.txt → VID10_001440.txt
# Renamed: VID_10_001441.txt → VID10_001441.txt
# Renamed: VID_10_001442.txt → VID10_001442.txt
# Renamed: VID_10_001443.txt → VID10_001443.txt
# Renamed: VID_10_001444.txt → VID10_001444.txt
# Renamed: VID_10_001445.txt → VID10_001445.txt
# Renamed: VID_10_001446.txt → VID10_001446.txt
# Renamed: VID_10_001447.txt → VID10_001447.txt
# Renamed: VID_10_001448.txt → VID10_001448.txt
# Renamed: VID_10_001449.txt → VID10_001449.txt
# Renamed: VID_10_001450.txt → VID10_001450.txt
# Renamed: VID_10_001451.txt → VID10_001451.txt
# Renamed: VID_10_001452.txt → VID10_001452.txt
# Renamed: VID_10_001453.txt → VID10_001453.txt
# Renamed: VID_10_001454.txt → VID10_001454.txt
# Renamed: VID_10_001455.txt → VID10_001455.txt
# Renamed: VID_10_001456.txt → VID10_001456.txt
# Renamed: VID_10_001457.txt → VID10_001457.txt
# Renamed: VID_10_001458.txt → VID10_001458.txt
# Renamed: VID_10_001459.txt → VID10_001459.txt
# Renamed: VID_10_001460.txt → VID10_001460.txt
# Renamed: VID_10_001461.txt → VID10_001461.txt
# Renamed: VID_10_001462.txt → VID10_001462.txt
# Renamed: VID_10_001463.txt → VID10_001463.txt
# Renamed: VID_10_001464.txt → VID10_001464.txt
# Renamed: VID_10_001465.txt → VID10_001465.txt
# Renamed: VID_10_001466.txt → VID10_001466.txt
# Renamed: VID_10_001467.txt → VID10_001467.txt
# Renamed: VID_10_001468.txt → VID10_001468.txt
# Renamed: VID_10_001469.txt → VID10_001469.txt
# Renamed: VID_10_001470.txt → VID10_001470.txt
# Renamed: VID_10_001471.txt → VID10_001471.txt
# Renamed: VID_10_001472.txt → VID10_001472.txt
# Renamed: VID_10_001473.txt → VID10_001473.txt
# Renamed: VID_10_001474.txt → VID10_001474.txt
# Renamed: VID_10_001475.txt → VID10_001475.txt
# Renamed: VID_10_001476.txt → VID10_001476.txt
# Renamed: VID_10_001477.txt → VID10_001477.txt
# Renamed: VID_10_001478.txt → VID10_001478.txt
# Renamed: VID_10_001479.txt → VID10_001479.txt
# Renamed: VID_10_001480.txt → VID10_001480.txt
# Renamed: VID_10_001481.txt → VID10_001481.txt
# Renamed: VID_10_001482.txt → VID10_001482.txt
# Renamed: VID_10_001483.txt → VID10_001483.txt
# Renamed: VID_10_001484.txt → VID10_001484.txt
# Renamed: VID_10_001485.txt → VID10_001485.txt
# Renamed: VID_10_001486.txt → VID10_001486.txt
# Renamed: VID_10_001487.txt → VID10_001487.txt
# Renamed: VID_10_001488.txt → VID10_001488.txt
# Renamed: VID_10_001489.txt → VID10_001489.txt
# Renamed: VID_10_001490.txt → VID10_001490.txt
# Renamed: VID_10_001491.txt → VID10_001491.txt
# Renamed: VID_10_001492.txt → VID10_001492.txt
# Renamed: VID_10_001493.txt → VID10_001493.txt
# Renamed: VID_10_001494.txt → VID10_001494.txt
# Renamed: VID_10_001495.txt → VID10_001495.txt
# Renamed: VID_10_001496.txt → VID10_001496.txt
# Renamed: VID_10_001497.txt → VID10_001497.txt
# Renamed: VID_10_001498.txt → VID10_001498.txt
# Renamed: VID_10_001499.txt → VID10_001499.txt
# Renamed: VID_10_001500.txt → VID10_001500.txt
# Renamed: VID_10_001501.txt → VID10_001501.txt
# Renamed: VID_10_001502.txt → VID10_001502.txt
# Renamed: VID_10_001503.txt → VID10_001503.txt
# Renamed: VID_10_001504.txt → VID10_001504.txt
# Renamed: VID_10_001505.txt → VID10_001505.txt
# Renamed: VID_10_001506.txt → VID10_001506.txt
# Renamed: VID_10_001507.txt → VID10_001507.txt
# Renamed: VID_10_001508.txt → VID10_001508.txt
# Renamed: VID_10_001509.txt → VID10_001509.txt
# Renamed: VID_10_001510.txt → VID10_001510.txt
# Renamed: VID_10_001511.txt → VID10_001511.txt
# Renamed: VID_10_001512.txt → VID10_001512.txt
# Renamed: VID_10_001513.txt → VID10_001513.txt
# Renamed: VID_10_001514.txt → VID10_001514.txt
# Renamed: VID_10_001515.txt → VID10_001515.txt
# Renamed: VID_10_001516.txt → VID10_001516.txt
# Renamed: VID_10_001517.txt → VID10_001517.txt
# Renamed: VID_10_001518.txt → VID10_001518.txt
# Renamed: VID_10_001519.txt → VID10_001519.txt
# Renamed: VID_10_001520.txt → VID10_001520.txt
# Renamed: VID_10_001521.txt → VID10_001521.txt
# Renamed: VID_10_001522.txt → VID10_001522.txt
# Renamed: VID_10_001523.txt → VID10_001523.txt
# Renamed: VID_10_001524.txt → VID10_001524.txt
# Renamed: VID_10_001525.txt → VID10_001525.txt
# Renamed: VID_10_001526.txt → VID10_001526.txt
# Renamed: VID_10_001527.txt → VID10_001527.txt
# Renamed: VID_10_001528.txt → VID10_001528.txt
# Renamed: VID_10_001529.txt → VID10_001529.txt
# Renamed: VID_10_001530.txt → VID10_001530.txt
# Renamed: VID_10_001531.txt → VID10_001531.txt
# Renamed: VID_10_001532.txt → VID10_001532.txt
# Renamed: VID_10_001533.txt → VID10_001533.txt
# Renamed: VID_10_001534.txt → VID10_001534.txt
# Renamed: VID_10_001535.txt → VID10_001535.txt
# Renamed: VID_10_001536.txt → VID10_001536.txt
# Renamed: VID_10_001537.txt → VID10_001537.txt
# Renamed: VID_10_001538.txt → VID10_001538.txt
# Renamed: VID_10_001539.txt → VID10_001539.txt
# Renamed: VID_10_001540.txt → VID10_001540.txt
# Renamed: VID_10_001541.txt → VID10_001541.txt
# Renamed: VID_10_001542.txt → VID10_001542.txt
# Renamed: VID_10_001543.txt → VID10_001543.txt
# Renamed: VID_10_001544.txt → VID10_001544.txt
# Renamed: VID_10_001545.txt → VID10_001545.txt
# Renamed: VID_10_001546.txt → VID10_001546.txt
# Renamed: VID_10_001547.txt → VID10_001547.txt
# Renamed: VID_10_001548.txt → VID10_001548.txt
# Renamed: VID_10_001549.txt → VID10_001549.txt
# Renamed: VID_10_001550.txt → VID10_001550.txt
# Renamed: VID_10_001551.txt → VID10_001551.txt
# Renamed: VID_10_001552.txt → VID10_001552.txt
# Renamed: VID_10_001553.txt → VID10_001553.txt
# Renamed: VID_10_001554.txt → VID10_001554.txt
# Renamed: VID_10_001555.txt → VID10_001555.txt
# Renamed: VID_10_001556.txt → VID10_001556.txt
# Renamed: VID_10_001557.txt → VID10_001557.txt
# Renamed: VID_10_001558.txt → VID10_001558.txt
# Renamed: VID_10_001559.txt → VID10_001559.txt
# Renamed: VID_10_001560.txt → VID10_001560.txt
# Renamed: VID_10_001561.txt → VID10_001561.txt
# Renamed: VID_10_001562.txt → VID10_001562.txt
# Renamed: VID_10_001563.txt → VID10_001563.txt
# Renamed: VID_10_001564.txt → VID10_001564.txt
# Renamed: VID_10_001565.txt → VID10_001565.txt
# Renamed: VID_10_001566.txt → VID10_001566.txt
# Renamed: VID_10_001567.txt → VID10_001567.txt
# Renamed: VID_10_001568.txt → VID10_001568.txt
# Renamed: VID_10_001569.txt → VID10_001569.txt
# Renamed: VID_10_001570.txt → VID10_001570.txt
# Renamed: VID_10_001571.txt → VID10_001571.txt
# Renamed: VID_10_001572.txt → VID10_001572.txt
# Renamed: VID_10_001573.txt → VID10_001573.txt
# Renamed: VID_10_001574.txt → VID10_001574.txt
# Renamed: VID_10_001575.txt → VID10_001575.txt
# Renamed: VID_10_001576.txt → VID10_001576.txt
# Renamed: VID_10_001577.txt → VID10_001577.txt
# Renamed: VID_10_001578.txt → VID10_001578.txt
# Renamed: VID_10_001579.txt → VID10_001579.txt
# Renamed: VID_10_001580.txt → VID10_001580.txt
# Renamed: VID_10_001581.txt → VID10_001581.txt
# Renamed: VID_10_001582.txt → VID10_001582.txt
# Renamed: VID_10_001583.txt → VID10_001583.txt
# Renamed: VID_10_001584.txt → VID10_001584.txt
# Renamed: VID_10_001585.txt → VID10_001585.txt
# Renamed: VID_10_001586.txt → VID10_001586.txt
# Renamed: VID_10_001587.txt → VID10_001587.txt
# Renamed: VID_10_001588.txt → VID10_001588.txt
# Renamed: VID_10_001589.txt → VID10_001589.txt
# Renamed: VID_10_001590.txt → VID10_001590.txt
# Renamed: VID_10_001591.txt → VID10_001591.txt
# Renamed: VID_10_001592.txt → VID10_001592.txt
# Renamed: VID_10_001593.txt → VID10_001593.txt
# Renamed: VID_10_001594.txt → VID10_001594.txt
# Renamed: VID_10_001595.txt → VID10_001595.txt
# Renamed: VID_10_001596.txt → VID10_001596.txt
# Renamed: VID_10_001597.txt → VID10_001597.txt
# Renamed: VID_10_001598.txt → VID10_001598.txt
# Renamed: VID_10_001599.txt → VID10_001599.txt
# Renamed: VID_10_001600.txt → VID10_001600.txt
# Renamed: VID_10_001601.txt → VID10_001601.txt
# Renamed: VID_10_001602.txt → VID10_001602.txt
# Renamed: VID_10_001603.txt → VID10_001603.txt
# Renamed: VID_10_001604.txt → VID10_001604.txt
# Renamed: VID_10_001605.txt → VID10_001605.txt
# Renamed: VID_10_001606.txt → VID10_001606.txt
# Renamed: VID_10_001607.txt → VID10_001607.txt
# Renamed: VID_10_001608.txt → VID10_001608.txt
# Renamed: VID_10_001609.txt → VID10_001609.txt
# Renamed: VID_10_001610.txt → VID10_001610.txt
# Renamed: VID_10_001611.txt → VID10_001611.txt
# Renamed: VID_10_001612.txt → VID10_001612.txt
# Renamed: VID_10_001613.txt → VID10_001613.txt
# Renamed: VID_10_001614.txt → VID10_001614.txt
# Renamed: VID_10_001615.txt → VID10_001615.txt
# Renamed: VID_10_001616.txt → VID10_001616.txt
# Renamed: VID_10_001617.txt → VID10_001617.txt
# Renamed: VID_10_001618.txt → VID10_001618.txt
# Renamed: VID_10_001619.txt → VID10_001619.txt
# Renamed: VID_10_001620.txt → VID10_001620.txt
# Renamed: VID_10_001621.txt → VID10_001621.txt
# Renamed: VID_10_001622.txt → VID10_001622.txt
# Renamed: VID_10_001623.txt → VID10_001623.txt
# Renamed: VID_10_001624.txt → VID10_001624.txt
# Renamed: VID_10_001625.txt → VID10_001625.txt
# Renamed: VID_10_001626.txt → VID10_001626.txt
# Renamed: VID_10_001627.txt → VID10_001627.txt
# Renamed: VID_10_001628.txt → VID10_001628.txt
# Renamed: VID_10_001629.txt → VID10_001629.txt
# Renamed: VID_10_001630.txt → VID10_001630.txt
# Renamed: VID_10_001631.txt → VID10_001631.txt
# Renamed: VID_10_001632.txt → VID10_001632.txt
# Renamed: VID_10_001633.txt → VID10_001633.txt
# Renamed: VID_10_001634.txt → VID10_001634.txt
# Renamed: VID_10_001635.txt → VID10_001635.txt
# Renamed: VID_10_001636.txt → VID10_001636.txt
# Renamed: VID_10_001637.txt → VID10_001637.txt
# Renamed: VID_10_001638.txt → VID10_001638.txt
# Renamed: VID_10_001639.txt → VID10_001639.txt
# Renamed: VID_10_001640.txt → VID10_001640.txt
# Renamed: VID_10_001641.txt → VID10_001641.txt
# Renamed: VID_10_001642.txt → VID10_001642.txt
# Renamed: VID_10_001643.txt → VID10_001643.txt
# Renamed: VID_10_001644.txt → VID10_001644.txt
# Renamed: VID_10_001645.txt → VID10_001645.txt
# Renamed: VID_10_001646.txt → VID10_001646.txt
# Renamed: VID_10_001647.txt → VID10_001647.txt
# Renamed: VID_10_001648.txt → VID10_001648.txt
# Renamed: VID_10_001649.txt → VID10_001649.txt
# Renamed: VID_10_001650.txt → VID10_001650.txt
# Renamed: VID_10_001651.txt → VID10_001651.txt
# Renamed: VID_10_001652.txt → VID10_001652.txt
# Renamed: VID_10_001653.txt → VID10_001653.txt
# Renamed: VID_10_001654.txt → VID10_001654.txt
# Renamed: VID_10_001655.txt → VID10_001655.txt
# Renamed: VID_10_001656.txt → VID10_001656.txt
# Renamed: VID_10_001657.txt → VID10_001657.txt
# Renamed: VID_10_001658.txt → VID10_001658.txt
# Renamed: VID_10_001659.txt → VID10_001659.txt
# Renamed: VID_10_001660.txt → VID10_001660.txt
# Renamed: VID_10_001661.txt → VID10_001661.txt
# Renamed: VID_10_001662.txt → VID10_001662.txt
# Renamed: VID_10_001663.txt → VID10_001663.txt
# Renamed: VID_10_001664.txt → VID10_001664.txt
# Renamed: VID_10_001665.txt → VID10_001665.txt
# Renamed: VID_10_001666.txt → VID10_001666.txt
# Renamed: VID_10_001667.txt → VID10_001667.txt
# Renamed: VID_10_001668.txt → VID10_001668.txt
# Renamed: VID_10_001669.txt → VID10_001669.txt
# Renamed: VID_10_001670.txt → VID10_001670.txt
# Renamed: VID_10_001671.txt → VID10_001671.txt
# Renamed: VID_10_001672.txt → VID10_001672.txt
# Renamed: VID_10_001673.txt → VID10_001673.txt
# Renamed: VID_10_001674.txt → VID10_001674.txt
# Renamed: VID_10_001675.txt → VID10_001675.txt
# Renamed: VID_10_001676.txt → VID10_001676.txt
# Renamed: VID_10_001677.txt → VID10_001677.txt
# Renamed: VID_10_001678.txt → VID10_001678.txt
# Renamed: VID_10_001679.txt → VID10_001679.txt
# Renamed: VID_10_001680.txt → VID10_001680.txt
# Renamed: VID_10_001681.txt → VID10_001681.txt
# Renamed: VID_10_001682.txt → VID10_001682.txt
# Renamed: VID_10_001683.txt → VID10_001683.txt
# Renamed: VID_10_001684.txt → VID10_001684.txt
# Renamed: VID_10_001685.txt → VID10_001685.txt
# Renamed: VID_10_001686.txt → VID10_001686.txt
# Renamed: VID_10_001687.txt → VID10_001687.txt
# Renamed: VID_10_001688.txt → VID10_001688.txt
# Renamed: VID_10_001689.txt → VID10_001689.txt
# Renamed: VID_10_001690.txt → VID10_001690.txt
# Renamed: VID_10_001691.txt → VID10_001691.txt
# Renamed: VID_10_001692.txt → VID10_001692.txt
# Renamed: VID_10_001693.txt → VID10_001693.txt
# Renamed: VID_10_001694.txt → VID10_001694.txt
# Renamed: VID_10_001695.txt → VID10_001695.txt
# Renamed: VID_10_001696.txt → VID10_001696.txt
# Renamed: VID_10_001697.txt → VID10_001697.txt
# Renamed: VID_10_001698.txt → VID10_001698.txt
# Renamed: VID_10_001699.txt → VID10_001699.txt
# Renamed: VID_10_001700.txt → VID10_001700.txt
# Renamed: VID_10_001701.txt → VID10_001701.txt
# Renamed: VID_10_001702.txt → VID10_001702.txt
# Renamed: VID_10_001703.txt → VID10_001703.txt
# Renamed: VID_10_001704.txt → VID10_001704.txt
# Renamed: VID_10_001705.txt → VID10_001705.txt
# Renamed: VID_10_001706.txt → VID10_001706.txt
# Renamed: VID_10_001707.txt → VID10_001707.txt
# Renamed: VID_10_001708.txt → VID10_001708.txt
# Renamed: VID_10_001709.txt → VID10_001709.txt
# Renamed: VID_10_001710.txt → VID10_001710.txt
# Renamed: VID_10_001711.txt → VID10_001711.txt
# Renamed: VID_10_001712.txt → VID10_001712.txt
# Renamed: VID_10_001713.txt → VID10_001713.txt
# Renamed: VID_10_001714.txt → VID10_001714.txt
# Renamed: VID_10_001715.txt → VID10_001715.txt
# Renamed: VID_10_001716.txt → VID10_001716.txt
# Renamed: VID_10_001717.txt → VID10_001717.txt
# Renamed: VID_10_001718.txt → VID10_001718.txt
# Renamed: VID_10_001719.txt → VID10_001719.txt
# Renamed: VID_10_001720.txt → VID10_001720.txt
# Renamed: VID_10_001721.txt → VID10_001721.txt
# Renamed: VID_10_001722.txt → VID10_001722.txt
# Renamed: VID_10_001723.txt → VID10_001723.txt
# Renamed: VID_10_001724.txt → VID10_001724.txt
# Renamed: VID_10_001725.txt → VID10_001725.txt
# Renamed: VID_10_001726.txt → VID10_001726.txt
# Renamed: VID_10_001727.txt → VID10_001727.txt
# Renamed: VID_10_001728.txt → VID10_001728.txt
# Renamed: VID_10_001729.txt → VID10_001729.txt
# Renamed: VID_10_001730.txt → VID10_001730.txt
# Renamed: VID_10_001731.txt → VID10_001731.txt
# Renamed: VID_10_001732.txt → VID10_001732.txt
# Renamed: VID_10_001733.txt → VID10_001733.txt
# Renamed: VID_10_001734.txt → VID10_001734.txt
# Renamed: VID_10_001735.txt → VID10_001735.txt
# Renamed: VID_10_001736.txt → VID10_001736.txt
# Renamed: VID_10_001737.txt → VID10_001737.txt
# Renamed: VID_10_001738.txt → VID10_001738.txt
# Renamed: VID_10_001739.txt → VID10_001739.txt
# Renamed: VID_10_001740.txt → VID10_001740.txt
# Renamed: VID_10_001741.txt → VID10_001741.txt
# Renamed: VID_10_001742.txt → VID10_001742.txt
# Renamed: VID_10_001743.txt → VID10_001743.txt
# Renamed: VID_10_001744.txt → VID10_001744.txt
# Renamed: VID_10_001745.txt → VID10_001745.txt
# Renamed: VID_10_001746.txt → VID10_001746.txt
# Renamed: VID_10_001747.txt → VID10_001747.txt
# Renamed: VID_10_001748.txt → VID10_001748.txt
# Renamed: VID_10_001749.txt → VID10_001749.txt

# %% [markdown]
# #### 3) Identify the label id and their respective names

# %%
### We have to match now the cleansed images with their respective annotations from the folders to be able to pair up
### For YOLO Classification, lets say we have VID02_000042.png, we would have to have VID02_000042.txt to pair for the task
### We can do this by recursively verifying the folders and matching with regular expressions

annotVID02bu = Path('./annot_backup\VID02')
annotVID04bu = Path('./annot_backup\VID04')
annotVID05bu = Path('./annot_backup\VID05')
annotVID06bu = Path('./annot_backup\VID06')
annotVID10bu = Path('./annot_backup\VID10')

ann_foldersbu = [annotVID02bu, annotVID04bu, annotVID05bu, annotVID06bu, annotVID10bu]

out_dir  = Path("./organizedAnnot")
out_dir.mkdir(exist_ok=True)

img_re = re.compile(r"^(.+?)\.png$", re.I)

image_count = 0
match_count = 0
unmatched_images = []

for img_path in imgData.rglob("*.png"):
    image_count += 1
    m = img_re.match(img_path.name)
    if not m:
        unmatched_images.append(str(img_path))
        continue

    base = m.group(1)  # captured text before .png
    found = False

    # search each annotation folder recursively; use regex to match ann stem
    ann_pattern = re.compile(rf"^{re.escape(base)}$", re.I)
    for ann_root in ann_foldersbu:
        for ann in ann_root.rglob("*.txt"):
            if ann_pattern.match(ann.stem):
                shutil.copy(ann, out_dir / ann.name)
                match_count += 1
                found = True
                break
        if found:
            break

    if not found:
        unmatched_images.append(str(img_path))

print("Total images found:", image_count)
print("Annotations matched and copied:", match_count)
print("Unmatched images:", len(unmatched_images))
# optional: print details
for p in unmatched_images:
    print("  -", p)
# Out:
# Total images found: 3779
# Annotations matched and copied: 3779
# Unmatched images: 0

# %% [markdown]
# #### 4) Setup folder structure

# %%
from pathlib import Path

# Paths to annotation folders
ann_foldersbu = [annotVID02bu, annotVID04bu, annotVID05bu, annotVID06bu, annotVID10bu]

label_ids = set()  # use a set to avoid duplicates

for folder in ann_foldersbu:
    for txt_file in folder.rglob("*.txt"):
        try:
            with open(txt_file, "r") as f:
                content = f.read().strip()
                if content:  # skip empty files
                    label_id = int(content)
                    label_ids.add(label_id)
        except Exception as e:
            print(f"Error reading {txt_file}: {e}")

# Convert to sorted list
unique_labels = sorted(label_ids)
print("Unique label IDs:", unique_labels)
print("Total unique labels:", len(unique_labels))
# Out:
# Unique label IDs: [-1, 3, 4, 7, 8, 10, 11, 12, 13, 15, 17, 18, 19, 20, 21, 22, 23, 26, 29, 44, 45, 46, 51, 52, 57, 58, 59, 60, 61, 66, 68, 69, 72, 78, 79, 82, 90, 92, 94, 95, 96, 97, 98, 99]
# Total unique labels: 44

# %% [markdown]
# #### 5) Populate structure to begin inferencing on main script

# %%
NAMES = [
  'bipolar,coagulate,abdominal-wall/cavity',
  'bipolar,coagulate,blood-vessel',
  'bipolar,coagulate,cystic-artery',
  'bipolar,coagulate,cystic-duct',
  'bipolar,coagulate,cystic-pedicle',
  'bipolar,coagulate,cystic-plate',
  'bipolar,coagulate,gallbladder',
  'bipolar,coagulate,liver',
  'bipolar,coagulate,omentum',
  'bipolar,coagulate,peritoneum',
  'bipolar,dissect,adhesion',
  'bipolar,dissect,cystic-artery',
  'bipolar,dissect,cystic-duct',
  'bipolar,dissect,cystic-plate',
  'bipolar,dissect,gallbladder',
  'bipolar,dissect,omentum',
  'bipolar,grasp,cystic-plate',
  'bipolar,grasp,liver',
  'bipolar,grasp,specimen-bag',
  'bipolar,null-verb,null-target',
  'bipolar,retract,blood-vessel',
  'bipolar,retract,cystic-pedicle',
  'bipolar,retract,gallbladder',
  'bipolar,retract,liver',
  'bipolar,retract,omentum',
  'clipper,clip,blood-vessel',
  'clipper,clip,cystic-artery',
  'clipper,clip,cystic-duct',
  'clipper,clip,cystic-pedicle',
  'clipper,clip,cystic-plate',
  'clipper,null-verb,null-target',
  'grasper,dissect,cystic-plate',
  'grasper,dissect,gallbladder',
  'grasper,dissect,omentum',
  'grasper,grasp,cystic-artery',
  'grasper,grasp,cystic-duct',
  'grasper,grasp,cystic-pedicle',
  'grasper,grasp,cystic-plate',
  'grasper,grasp,gallbladder',
  'grasper,grasp,gut',
  'grasper,grasp,liver',
  'grasper,grasp,omentum',
  'grasper,grasp,peritoneum',
  'grasper,grasp,specimen-bag',
  'grasper,null-verb,null-target',
  'grasper,pack,gallbladder',
  'grasper,retract,cystic-duct',
  'grasper,retract,cystic-pedicle',
  'grasper,retract,cystic-plate',
  'grasper,retract,gallbladder',
  'grasper,retract,gut',
  'grasper,retract,liver',
  'grasper,retract,omentum',
  'grasper,retract,peritoneum',
  'hook,coagulate,blood-vessel',
  'hook,coagulate,cystic-artery',
  'hook,coagulate,cystic-duct',
  'hook,coagulate,cystic-pedicle',
  'hook,coagulate,cystic-plate',
  'hook,coagulate,gallbladder',
  'hook,coagulate,liver',
  'hook,coagulate,omentum',
  'hook,cut,blood-vessel',
  'hook,cut,peritoneum',
  'hook,dissect,blood-vessel',
  'hook,dissect,cystic-artery',
  'hook,dissect,cystic-duct',
  'hook,dissect,cystic-plate',
  'hook,dissect,gallbladder',
  'hook,dissect,omentum',
  'hook,dissect,peritoneum',
  'hook,null-verb,null-target',
  'hook,retract,gallbladder',
  'hook,retract,liver',
  'irrigator,aspirate,fluid',
  'irrigator,dissect,cystic-duct',
  'irrigator,dissect,cystic-pedicle',
  'irrigator,dissect,cystic-plate',
  'irrigator,dissect,gallbladder',
  'irrigator,dissect,omentum',
  'irrigator,irrigate,abdominal-wall/cavity',
  'irrigator,irrigate,cystic-pedicle',
  'irrigator,irrigate,liver',
  'irrigator,null-verb,null-target',
  'irrigator,retract,gallbladder',
  'irrigator,retract,liver',
  'irrigator,retract,omentum',
  'scissors,coagulate,omentum',
  'scissors,cut,adhesion',
  'scissors,cut,blood-vessel',
  'scissors,cut,cystic-artery',
  'scissors,cut,cystic-duct',
  'scissors,cut,cystic-plate',
  'scissors,cut,liver',
  'scissors,cut,omentum',
  'scissors,cut,peritoneum',
  'scissors,dissect,cystic-plate',
  'scissors,dissect,gallbladder',
  'scissors,dissect,omentum',
  'scissors,null-verb,null-target',
]

# %%
from pathlib import Path
import shutil
from collections import defaultdict
from math import ceil

# === PATHS ===
IMG_ROOT = imgData
ANNOT_ROOT = Path("./organizedAnnot/")
OUTPUT_ROOT = Path("./YOLO_dataset")

SPLIT_RATIOS = {"train": 0.7, "val": 0.15, "test": 0.15}

def sanitize(name: str) -> str:
    return name.replace("/", "_").replace(",", "_").replace(" ", "_")

# ========= STEP 1: COLLECT IMAGES PER CLASS =========
class_to_images = defaultdict(list)

for ann_file in ANNOT_ROOT.rglob("*.txt"):
    img_file = IMG_ROOT / (ann_file.stem + ".png")
    if not img_file.exists():
        continue
    try:
        idx = int(ann_file.read_text().strip())
        class_name = NAMES[idx]
        class_to_images[class_name].append(img_file)
    except:
        continue

# ========= STEP 2: DETERMINE BALANCED CLASS COUNT =========
# Maximum number of images any class has
max_images = max(len(imgs) for imgs in class_to_images.values())

# Number of images for each split PER CLASS
train_n = int(max_images * SPLIT_RATIOS["train"])
val_n   = int(max_images * SPLIT_RATIOS["val"])
test_n  = max_images - train_n - val_n  # remaining

print(f"Per-class counts → Train={train_n}, Val={val_n}, Test={test_n}")

# ========= STEP 3: CREATE OUTPUT STRUCTURE =========
for split in ["train", "val", "test"]:
    (OUTPUT_ROOT / split).mkdir(parents=True, exist_ok=True)

# ========= STEP 4: BALANCED SAMPLING & COPYING =========
def oversample(images, needed):
    """Return exactly `needed` images (repeat if necessary)."""
    if len(images) == 0:
        return []  # shouldn't happen
    out = []
    while len(out) < needed:
        out.extend(images)
    return out[:needed]

for class_name, img_list in class_to_images.items():

    # Oversample as needed for each split
    train_imgs = oversample(img_list, train_n)
    val_imgs   = oversample(img_list, val_n)
    test_imgs  = oversample(img_list, test_n)

    # Create class subfolders
    for split in ["train", "val", "test"]:
        (OUTPUT_ROOT / split / sanitize(class_name)).mkdir(parents=True, exist_ok=True)

    # Copy files
    for img in train_imgs:
        shutil.copy(img, OUTPUT_ROOT / "train" / sanitize(class_name) / img.name)

    for img in val_imgs:
        shutil.copy(img, OUTPUT_ROOT / "val" / sanitize(class_name) / img.name)

    for img in test_imgs:
        shutil.copy(img, OUTPUT_ROOT / "test" / sanitize(class_name) / img.name)

print("Balanced dataset creation complete.")
# Out:
# Per-class counts → Train=1043, Val=223, Test=225
# Balanced dataset creation complete.

# %%
from pathlib import Path
from collections import defaultdict

YOLO_ROOT = Path("./YOLO_dataset")

splits = ["train", "val", "test"]

counts = {split: defaultdict(int) for split in splits}

for split in splits:
    split_path = YOLO_ROOT / split
    if not split_path.exists():
        print(f"Missing split folder: {split}")
        continue

    # Each class is a subfolder
    for class_folder in split_path.iterdir():
        if class_folder.is_dir():
            class_name = class_folder.name
            num_images = len(list(class_folder.glob("*.png")))
            counts[split][class_name] = num_images

# ==== Print summary ====
print("=== CLASS DISTRIBUTION ===")
for split in splits:
    print(f"\n--- {split.upper()} ---")
    for class_name, num_images in sorted(counts[split].items()):
        print(f"{class_name:30} : {num_images}")
# Out:
# === CLASS DISTRIBUTION ===
#
# --- TRAIN ---
# bipolar_coagulate_cystic-duct  : 10
# bipolar_coagulate_cystic-pedicle : 47
# bipolar_coagulate_liver        : 469
# bipolar_dissect_adhesion       : 23
# bipolar_dissect_cystic-duct    : 65
# bipolar_dissect_cystic-plate   : 2
# bipolar_grasp_liver            : 1043
# bipolar_grasp_specimen-bag     : 5
# bipolar_null-verb_null-target  : 426
# bipolar_retract_blood-vessel   : 83
# bipolar_retract_cystic-pedicle : 7
# bipolar_retract_liver          : 14
# clipper_clip_cystic-artery     : 6
# clipper_clip_cystic-plate      : 42
# grasper_null-verb_null-target  : 1
# grasper_pack_gallbladder       : 2
# grasper_retract_liver          : 2
# grasper_retract_omentum        : 3
# hook_coagulate_cystic-pedicle  : 33
# hook_coagulate_cystic-plate    : 113
# hook_coagulate_gallbladder     : 20
# hook_coagulate_liver           : 561
# hook_coagulate_omentum         : 6
# hook_dissect_cystic-duct       : 14
# hook_dissect_gallbladder       : 8
# hook_dissect_omentum           : 16
# hook_retract_gallbladder       : 2
# irrigator_dissect_gallbladder  : 3
# irrigator_dissect_omentum      : 63
# irrigator_irrigate_liver       : 13
# scissors_cut_cystic-artery     : 1
# scissors_cut_cystic-plate      : 1
# scissors_cut_omentum           : 44
# scissors_cut_peritoneum        : 8
# scissors_dissect_cystic-plate  : 37
# scissors_dissect_gallbladder   : 5
# scissors_dissect_omentum       : 2
# scissors_null-verb_null-target : 131
#
# --- VAL ---
# bipolar_coagulate_cystic-duct  : 10
# bipolar_coagulate_cystic-pedicle : 47
# bipolar_coagulate_liver        : 223
# bipolar_dissect_adhesion       : 23
# bipolar_dissect_cystic-duct    : 65
# bipolar_dissect_cystic-plate   : 2
# bipolar_grasp_liver            : 223
# bipolar_grasp_specimen-bag     : 5
# bipolar_null-verb_null-target  : 223
# bipolar_retract_blood-vessel   : 83
# bipolar_retract_cystic-pedicle : 7
# bipolar_retract_liver          : 14
# clipper_clip_cystic-artery     : 6
# clipper_clip_cystic-plate      : 42
# grasper_null-verb_null-target  : 1
# grasper_pack_gallbladder       : 2
# grasper_retract_liver          : 2
# grasper_retract_omentum        : 3
# hook_coagulate_cystic-pedicle  : 33
# hook_coagulate_cystic-plate    : 113
# hook_coagulate_gallbladder     : 20
# hook_coagulate_liver           : 223
# hook_coagulate_omentum         : 6
# hook_dissect_cystic-duct       : 14
# hook_dissect_gallbladder       : 8
# hook_dissect_omentum           : 16
# hook_retract_gallbladder       : 2
# irrigator_dissect_gallbladder  : 3
# irrigator_dissect_omentum      : 63
# irrigator_irrigate_liver       : 13
# scissors_cut_cystic-artery     : 1
# scissors_cut_cystic-plate      : 1
# scissors_cut_omentum           : 44
# scissors_cut_peritoneum        : 8
# scissors_dissect_cystic-plate  : 37
# scissors_dissect_gallbladder   : 5
# scissors_dissect_omentum       : 2
# scissors_null-verb_null-target : 131
#
# --- TEST ---
# bipolar_coagulate_cystic-duct  : 10
# bipolar_coagulate_cystic-pedicle : 47
# bipolar_coagulate_liver        : 225
# bipolar_dissect_adhesion       : 23
# bipolar_dissect_cystic-duct    : 65
# bipolar_dissect_cystic-plate   : 2
# bipolar_grasp_liver            : 225
# bipolar_grasp_specimen-bag     : 5
# bipolar_null-verb_null-target  : 225
# bipolar_retract_blood-vessel   : 83
# bipolar_retract_cystic-pedicle : 7
# bipolar_retract_liver          : 14
# clipper_clip_cystic-artery     : 6
# clipper_clip_cystic-plate      : 42
# grasper_null-verb_null-target  : 1
# grasper_pack_gallbladder       : 2
# grasper_retract_liver          : 2
# grasper_retract_omentum        : 3
# hook_coagulate_cystic-pedicle  : 33
# hook_coagulate_cystic-plate    : 113
# hook_coagulate_gallbladder     : 20
# hook_coagulate_liver           : 225
# hook_coagulate_omentum         : 6
# hook_dissect_cystic-duct       : 14
# hook_dissect_gallbladder       : 8
# hook_dissect_omentum           : 16
# hook_retract_gallbladder       : 2
# irrigator_dissect_gallbladder  : 3
# irrigator_dissect_omentum      : 63
# irrigator_irrigate_liver       : 13
# scissors_cut_cystic-artery     : 1
# scissors_cut_cystic-plate      : 1
# scissors_cut_omentum           : 44
# scissors_cut_peritoneum        : 8
# scissors_dissect_cystic-plate  : 37
# scissors_dissect_gallbladder   : 5
# scissors_dissect_omentum       : 2
# scissors_null-verb_null-target : 131

# %%
from pathlib import Path

YOLO_ROOT = Path("./YOLO_dataset")
splits = ["train", "val", "test"]

for split in splits:
    split_path = YOLO_ROOT / split
    if not split_path.exists():
        print(f"{split} folder missing.")
        continue

    # Count only directories (each one is a class)
    class_folders = [p for p in split_path.iterdir() if p.is_dir()]
    print(f"{split.upper()} → {len(class_folders)} class folders")
# Out:
# TRAIN → 38 class folders
# VAL → 38 class folders
# TEST → 38 class folders
